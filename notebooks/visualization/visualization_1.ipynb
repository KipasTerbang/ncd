# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari CSV
df1 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_b_16\clustering_results_vit_b_16_finetuned_42labeled_10unlabeled_FINCH_KMEANS.csv")
df1_trials = df1[df1['trial'] != 'Average'].copy()
df1_trials['FINCH_ACC'] = pd.to_numeric(df1_trials['FINCH_ACC'])
df1_trials['FINCH_NMI'] = pd.to_numeric(df1_trials['FINCH_NMI'])
max1_acc_idx = df1_trials['FINCH_ACC'].idxmax()
max1_nmi_idx = df1_trials['FINCH_NMI'].idxmax()

df2 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_l_16\clustering_results_vit_l_16_finetuned_42labeled_10unlabeled_FINCH_KMEANS.csv")
df2_trials = df2[df2['trial'] != 'Average'].copy()
df2_trials['FINCH_ACC'] = pd.to_numeric(df2_trials['FINCH_ACC'])
df2_trials['FINCH_NMI'] = pd.to_numeric(df2_trials['FINCH_NMI'])
max2_acc_idx = df2_trials['FINCH_ACC'].idxmax()
max2_nmi_idx = df2_trials['FINCH_NMI'].idxmax()

# Plot1
plt.figure(figsize=(10, 6))
plt.plot(df1_trials['trial'], df1_trials['FINCH_ACC'], marker='o', label='ViT-B/16')
plt.plot(df1_trials.loc[max1_acc_idx, 'trial'], df1_trials.loc[max1_acc_idx, 'FINCH_ACC'], 
         'ro', label=f"ViT-B/16-Top ACC: {df1_trials.loc[max1_acc_idx, 'FINCH_ACC']:.3f}")
# plt.plot(df1_trials['trial'], df1_trials['FINCH_NMI'], marker='o', label='ViT-B/16')
# plt.plot(df1_trials.loc[max1_nmi_idx, 'trial'], df1_trials.loc[max1_nmi_idx, 'FINCH_NMI'], 
#          'ro', label=f"ViT-B/16-Top NMI: {df1_trials.loc[max1_nmi_idx, 'FINCH_NMI']:.3f}")

# Plot2
plt.plot(df2_trials['trial'], df2_trials['FINCH_ACC'], marker='o', label='ViT-L/16')
plt.plot(df2_trials.loc[max2_acc_idx, 'trial'], df2_trials.loc[max2_acc_idx, 'FINCH_ACC'], 
         'ro', label=f"ViT-L/16-Top ACC: {df2_trials.loc[max2_acc_idx, 'FINCH_ACC']:.3f}")
# plt.plot(df2_trials['trial'], df2_trials['FINCH_NMI'], marker='o', label='ViT-L/16')
# plt.plot(df2_trials.loc[max2_nmi_idx, 'trial'], df2_trials.loc[max2_nmi_idx, 'FINCH_NMI'], 
#          'ro', label=f"ViT-L/16-Top NMI: {df2_trials.loc[max2_nmi_idx, 'FINCH_NMI']:.3f}")

plt.xlabel('Trial')
plt.ylabel('Score')
plt.title('FINCH Accuracy per Trial (42 Labeled / 10 Unlabeled Classes)')
# plt.title('FINCH NMI per Trial (42 Labeled / 10 Unlabeled Classes)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


# plt.figure(figsize=(10, 6))
# plt.bar(df_trials['trial'], df_trials['FINCH_Num_Clusters'], color='skyblue')
# plt.xlabel('Trial')
# plt.ylabel('Number of Clusters')
# plt.title('Number of Clusters Formed by FINCH per Trial')
# plt.grid(axis='y')
# plt.tight_layout()
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari CSV
df1 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_b_16\clustering_results_vit_b_16_finetuned_42labeled_10unlabeled_FINCH_KMEANS.csv")
df1_trials = df1[df1['trial'] != 'Average'].copy()
df1_trials['FINCH_ACC'] = pd.to_numeric(df1_trials['FINCH_ACC'])
df1_trials['FINCH_NMI'] = pd.to_numeric(df1_trials['FINCH_NMI'])
max1_finch_acc_idx = df1_trials['FINCH_ACC'].idxmax()
max1_finch_nmi_idx = df1_trials['FINCH_NMI'].idxmax()

df2 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\pretrained\vit_b_16\clustering_results_vit_b_16_pretrained_42labeled_10unlabeled_FINCH_KMEANS.csv")
df2_trials = df2[df2['trial'] != 'Average'].copy()
df2_trials['FINCH_ACC'] = pd.to_numeric(df2_trials['FINCH_ACC'])
df2_trials['FINCH_NMI'] = pd.to_numeric(df2_trials['FINCH_NMI'])
max2_finch_acc_idx = df2_trials['FINCH_ACC'].idxmax()
max2_finch_nmi_idx = df2_trials['FINCH_NMI'].idxmax()

df3 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_l_16\clustering_results_vit_l_16_finetuned_42labeled_10unlabeled_FINCH_KMEANS.csv")
df3_trials = df3[df3['trial'] != 'Average'].copy()
df3_trials['FINCH_ACC'] = pd.to_numeric(df3_trials['FINCH_ACC'])
df3_trials['FINCH_NMI'] = pd.to_numeric(df3_trials['FINCH_NMI'])
max3_finch_acc_idx = df3_trials['FINCH_ACC'].idxmax()
max3_finch_nmi_idx = df3_trials['FINCH_NMI'].idxmax()

df4 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\pretrained\vit_l_16\clustering_results_vit_l_16_pretrained_42labeled_10unlabeled_FINCH_KMEANS.csv")
df4_trials = df4[df4['trial'] != 'Average'].copy()
df4_trials['FINCH_ACC'] = pd.to_numeric(df4_trials['FINCH_ACC'])
df4_trials['FINCH_NMI'] = pd.to_numeric(df4_trials['FINCH_NMI'])
max4_finch_acc_idx = df4_trials['FINCH_ACC'].idxmax()
max4_finch_nmi_idx = df4_trials['FINCH_NMI'].idxmax()

# Plot1
plt.figure(figsize=(10, 4))
# plt.plot(df1_trials['trial'], df1_trials['FINCH_ACC'], marker='o', label='ViT-B/16 (dilatih ulang)')
# plt.plot(df1_trials.loc[max1_finch_acc_idx, 'trial'], df1_trials.loc[max1_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-B/16(dilatih ulang)-Top ACC: {df1_trials.loc[max1_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df1_trials['trial'], df1_trials['FINCH_NMI'], marker='o', label='ViT-B/16 (dilatih ulang)')
plt.plot(df1_trials.loc[max1_finch_nmi_idx, 'trial'], df1_trials.loc[max1_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-B/16(dilatih ulang)-Top NMI: {df1_trials.loc[max1_finch_nmi_idx, 'FINCH_NMI']:.3f}")

# Plot2
# plt.plot(df2_trials['trial'], df2_trials['FINCH_ACC'], marker='o', label='ViT-B/16 (pretrained)')
# plt.plot(df2_trials.loc[max2_finch_acc_idx, 'trial'], df2_trials.loc[max2_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-B/16(pretrained)-Top ACC: {df2_trials.loc[max2_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df2_trials['trial'], df2_trials['FINCH_NMI'], marker='o', label='ViT-B/16 (pretrained)')
plt.plot(df2_trials.loc[max2_finch_nmi_idx, 'trial'], df2_trials.loc[max2_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-B/16(pretrained)-Top NMI: {df2_trials.loc[max2_finch_nmi_idx, 'FINCH_NMI']:.3f}")

# Plot3
# plt.plot(df3_trials['trial'], df3_trials['FINCH_ACC'], marker='o', label='ViT-L/16 (dilatih ulang)')
# plt.plot(df3_trials.loc[max3_finch_acc_idx, 'trial'], df3_trials.loc[max3_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-L/16(dilatih ulang)-Top ACC: {df3_trials.loc[max3_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df3_trials['trial'], df3_trials['FINCH_NMI'], marker='o', label='ViT-L/16 (dilatih ulang)')
plt.plot(df3_trials.loc[max3_finch_nmi_idx, 'trial'], df3_trials.loc[max3_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-L/16(dilatih ulang)-Top NMI: {df3_trials.loc[max3_finch_nmi_idx, 'FINCH_NMI']:.3f}")

# Plot4
# plt.plot(df4_trials['trial'], df4_trials['FINCH_ACC'], marker='o', color='purple', label='ViT-L/16 (pretrained)')
# plt.plot(df4_trials.loc[max4_finch_acc_idx, 'trial'], df4_trials.loc[max4_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-L/16(pretrained)-Top ACC: {df4_trials.loc[max4_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df4_trials['trial'], df4_trials['FINCH_NMI'], marker='o', color='purple', label='ViT-L/16 (pretrained)')
plt.plot(df4_trials.loc[max4_finch_nmi_idx, 'trial'], df4_trials.loc[max4_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-L/16(pretrained)-Top NMI: {df4_trials.loc[max4_finch_nmi_idx, 'FINCH_NMI']:.3f}")


plt.xlabel('Trial')
plt.ylabel('Score')
plt.title('FINCH Accuracy per Trial (42 Labeled / 10 Unlabeled Classes)')
# plt.title('FINCH NMI per Trial (12 Labeled / 40 Unlabeled Classes)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari CSV
df1 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_b_16\clustering_results_vit_b_16_finetuned_42labeled_10unlabeled_FINCH_KMEANS.csv")
df1_trials = df1[df1['trial'] != 'Average'].copy()
df1_trials['FINCH_ACC'] = pd.to_numeric(df1_trials['FINCH_ACC'])
df1_trials['FINCH_NMI'] = pd.to_numeric(df1_trials['FINCH_NMI'])
df1_trials['KMeans_ACC'] = pd.to_numeric(df1_trials['KMeans_ACC'])
df1_trials['KMeans_NMI'] = pd.to_numeric(df1_trials['KMeans_NMI'])
max1_finch_acc_idx = df1_trials['FINCH_ACC'].idxmax()
max1_finch_nmi_idx = df1_trials['FINCH_NMI'].idxmax()
max1_kmeans_acc_idx = df1_trials['KMeans_ACC'].idxmax()
max1_kmeans_nmi_idx = df1_trials['KMeans_NMI'].idxmax()

df2 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\pretrained\vit_b_16\clustering_results_vit_b_16_pretrained_42labeled_10unlabeled_FINCH_KMEANS.csv")
df2_trials = df2[df2['trial'] != 'Average'].copy()
df2_trials['FINCH_ACC'] = pd.to_numeric(df2_trials['FINCH_ACC'])
df2_trials['FINCH_NMI'] = pd.to_numeric(df2_trials['FINCH_NMI'])
df2_trials['KMeans_ACC'] = pd.to_numeric(df2_trials['KMeans_ACC'])
df2_trials['KMeans_NMI'] = pd.to_numeric(df2_trials['KMeans_NMI'])
max2_finch_acc_idx = df2_trials['FINCH_ACC'].idxmax()
max2_finch_nmi_idx = df2_trials['FINCH_NMI'].idxmax()
max2_kmeans_acc_idx = df2_trials['KMeans_ACC'].idxmax()
max2_kmeans_nmi_idx = df2_trials['KMeans_NMI'].idxmax()

# Baca data dari CSV
df3 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_l_16\clustering_results_vit_l_16_finetuned_42labeled_10unlabeled_FINCH_KMEANS.csv")
df3_trials = df3[df3['trial'] != 'Average'].copy()
df3_trials['FINCH_ACC'] = pd.to_numeric(df3_trials['FINCH_ACC'])
df3_trials['FINCH_NMI'] = pd.to_numeric(df3_trials['FINCH_NMI'])
df3_trials['KMeans_ACC'] = pd.to_numeric(df3_trials['KMeans_ACC'])
df3_trials['KMeans_NMI'] = pd.to_numeric(df3_trials['KMeans_NMI'])
max3_finch_acc_idx = df3_trials['FINCH_ACC'].idxmax()
max3_finch_nmi_idx = df3_trials['FINCH_NMI'].idxmax()
max3_kmeans_acc_idx = df3_trials['KMeans_ACC'].idxmax()
max3_kmeans_nmi_idx = df3_trials['KMeans_NMI'].idxmax()

df4 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\pretrained\vit_l_16\clustering_results_vit_l_16_pretrained_42labeled_10unlabeled_FINCH_KMEANS.csv")
df4_trials = df4[df4['trial'] != 'Average'].copy()
df4_trials['FINCH_ACC'] = pd.to_numeric(df4_trials['FINCH_ACC'])
df4_trials['FINCH_NMI'] = pd.to_numeric(df4_trials['FINCH_NMI'])
df4_trials['KMeans_ACC'] = pd.to_numeric(df4_trials['KMeans_ACC'])
df4_trials['KMeans_NMI'] = pd.to_numeric(df4_trials['KMeans_NMI'])
max4_finch_acc_idx = df4_trials['FINCH_ACC'].idxmax()
max4_finch_nmi_idx = df4_trials['FINCH_NMI'].idxmax()
max4_kmeans_acc_idx = df4_trials['KMeans_ACC'].idxmax()
max4_kmeans_nmi_idx = df4_trials['KMeans_NMI'].idxmax()

# Plot1
plt.figure(figsize=(10, 4))
# plt.plot(df1_trials['trial'], df1_trials['FINCH_ACC'], marker='o', label='ViT-B/16 (dilatih ulang) w/ FINCH')
# plt.plot(df1_trials.loc[max1_finch_acc_idx, 'trial'], df1_trials.loc[max1_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-B/16(dilatih ulang) w/ FINCH-Top ACC: {df1_trials.loc[max1_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df1_trials['trial'], df1_trials['FINCH_NMI'], marker='o', label='ViT-B/16 (dilatih ulang) w/ FINCH')
plt.plot(df1_trials.loc[max1_finch_nmi_idx, 'trial'], df1_trials.loc[max1_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-B/16(dilatih ulang) w/ FINCH-Top NMI: {df1_trials.loc[max1_finch_nmi_idx, 'FINCH_NMI']:.3f}")
# plt.plot(df1_trials['trial'], df1_trials['KMeans_ACC'], marker='o', label='ViT-B/16 (dilatih ulang) w/ K-Means')
# plt.plot(df1_trials.loc[max1_kmeans_acc_idx, 'trial'], df1_trials.loc[max1_kmeans_acc_idx, 'KMeans_ACC'], 
#          'ro', label=f"ViT-B/16(dilatih ulang) w/ K-Means-Top ACC: {df1_trials.loc[max1_kmeans_acc_idx, 'KMeans_ACC']:.3f}")
plt.plot(df1_trials['trial'], df1_trials['KMeans_NMI'], marker='o', label='ViT-B/16 (dilatih ulang) w/ K-Means')
plt.plot(df1_trials.loc[max1_kmeans_nmi_idx, 'trial'], df1_trials.loc[max1_kmeans_nmi_idx, 'KMeans_NMI'], 
         'ro', label=f"ViT-B/16(dilatih ulang) w/ K-Means-Top NMI: {df1_trials.loc[max1_kmeans_nmi_idx, 'KMeans_NMI']:.3f}")

# Plot2
# plt.plot(df2_trials['trial'], df2_trials['FINCH_ACC'], marker='o', label='ViT-B/16 (pretrained) w/ FINCH')
# plt.plot(df2_trials.loc[max2_finch_acc_idx, 'trial'], df2_trials.loc[max2_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-B/16(pretrained) w/ FINCH-Top ACC: {df2_trials.loc[max2_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df2_trials['trial'], df2_trials['FINCH_NMI'], marker='o', label='ViT-B/16 (pretrained) w/ FINCH')
plt.plot(df2_trials.loc[max2_finch_nmi_idx, 'trial'], df2_trials.loc[max2_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-B/16(pretrained) w/ FINCH-Top NMI: {df2_trials.loc[max2_finch_nmi_idx, 'FINCH_NMI']:.3f}")
# plt.plot(df2_trials['trial'], df2_trials['KMeans_ACC'], marker='o', label='ViT-B/16 (pretrained) w/ K-Means')
# plt.plot(df2_trials.loc[max2_kmeans_acc_idx, 'trial'], df2_trials.loc[max2_kmeans_acc_idx, 'KMeans_ACC'], 
#          'ro', label=f"ViT-B/16(pretrained) w/ K-Means-Top ACC: {df2_trials.loc[max2_kmeans_acc_idx, 'KMeans_ACC']:.3f}")
plt.plot(df2_trials['trial'], df2_trials['KMeans_NMI'], marker='o', label='ViT-B/16 (pretrained) w/ K-Means')
plt.plot(df2_trials.loc[max2_kmeans_nmi_idx, 'trial'], df2_trials.loc[max2_kmeans_nmi_idx, 'KMeans_NMI'], 
         'ro', label=f"ViT-B/16(pretrained) w/ K-Means-Top NMI: {df2_trials.loc[max2_kmeans_nmi_idx, 'KMeans_NMI']:.3f}")

# Plot3
# plt.plot(df3_trials['trial'], df3_trials['FINCH_ACC'], marker='o', label='ViT-L/16 (dilatih ulang) w/ FINCH')
# plt.plot(df3_trials.loc[max3_finch_acc_idx, 'trial'], df3_trials.loc[max3_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-L/16(dilatih ulang) w/ FINCH-Top ACC: {df3_trials.loc[max3_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df3_trials['trial'], df3_trials['FINCH_NMI'], marker='o', label='ViT-L/16 (dilatih ulang) w/ FINCH')
plt.plot(df3_trials.loc[max3_finch_nmi_idx, 'trial'], df3_trials.loc[max3_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-L/16(dilatih ulang) w/ FINCH-Top NMI: {df3_trials.loc[max3_finch_nmi_idx, 'FINCH_NMI']:.3f}")
# plt.plot(df3_trials['trial'], df3_trials['KMeans_ACC'], marker='o', label='ViT-L/16 (dilatih ulang) w/ K-Means')
# plt.plot(df3_trials.loc[max3_kmeans_acc_idx, 'trial'], df3_trials.loc[max3_kmeans_acc_idx, 'KMeans_ACC'], 
#          'ro', label=f"ViT-L/16(dilatih ulang) w/ K-Means-Top ACC: {df3_trials.loc[max3_kmeans_acc_idx, 'KMeans_ACC']:.3f}")
plt.plot(df3_trials['trial'], df3_trials['KMeans_NMI'], marker='o', label='ViT-L/16 (dilatih ulang) w/ K-Means')
plt.plot(df3_trials.loc[max3_kmeans_nmi_idx, 'trial'], df3_trials.loc[max3_kmeans_nmi_idx, 'KMeans_NMI'], 
         'ro', label=f"ViT-L/16(dilatih ulang) w/ K-Means-Top NMI: {df3_trials.loc[max3_kmeans_nmi_idx, 'KMeans_NMI']:.3f}")

# Plot4
# plt.plot(df4_trials['trial'], df4_trials['FINCH_ACC'], marker='o', label='ViT-L/16 (pretrained) w/ FINCH')
# plt.plot(df4_trials.loc[max4_finch_acc_idx, 'trial'], df4_trials.loc[max4_finch_acc_idx, 'FINCH_ACC'], 
#          'ro', label=f"ViT-L/16(pretrained) w/ FINCH-Top ACC: {df4_trials.loc[max4_finch_acc_idx, 'FINCH_ACC']:.3f}")
plt.plot(df4_trials['trial'], df4_trials['FINCH_NMI'], marker='o', label='ViT-L/16 (pretrained) w/ FINCH')
plt.plot(df4_trials.loc[max4_finch_nmi_idx, 'trial'], df4_trials.loc[max4_finch_nmi_idx, 'FINCH_NMI'], 
         'ro', label=f"ViT-L/16(pretrained) w/ FINCH-Top NMI: {df4_trials.loc[max4_finch_nmi_idx, 'FINCH_NMI']:.3f}")
# plt.plot(df4_trials['trial'], df4_trials['KMeans_ACC'], marker='o', label='ViT-L/16 (pretrained) w/ K-Means')
# plt.plot(df4_trials.loc[max4_kmeans_acc_idx, 'trial'], df4_trials.loc[max4_kmeans_acc_idx, 'KMeans_ACC'], 
#          'ro', label=f"ViT-L/16(pretrained) w/ K-Means-Top ACC: {df4_trials.loc[max4_kmeans_acc_idx, 'KMeans_ACC']:.3f}")
plt.plot(df4_trials['trial'], df4_trials['KMeans_NMI'], marker='o', label='ViT-L/16 (pretrained) w/ K-Means')
plt.plot(df4_trials.loc[max4_kmeans_nmi_idx, 'trial'], df4_trials.loc[max4_kmeans_nmi_idx, 'KMeans_NMI'], 
         'ro', label=f"ViT-L/16(pretrained) w/ K-Means-Top NMI: {df4_trials.loc[max4_kmeans_nmi_idx, 'KMeans_NMI']:.3f}")



plt.xlabel('Trial')
plt.ylabel('Score')
# plt.title('Accuracy per Trial (42 Labeled / 10 Unlabeled Classes)')
plt.title('NMI per Trial (42 Labeled / 10 Unlabeled Classes)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV pertama (finetuned)
df1 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_b_16\file1.csv")
df1_trials = df1[df1['trial'] != 'Average'].copy()
df1_trials['FINCH_ACC'] = pd.to_numeric(df1_trials['FINCH_ACC'])
df1_trials['FINCH_NMI'] = pd.to_numeric(df1_trials['FINCH_NMI'])

# Load CSV kedua (non-finetuned)
df2 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\nonfinetuned\vit_b_16\file2.csv")
df2_trials = df2[df2['trial'] != 'Average'].copy()
df2_trials['FINCH_ACC'] = pd.to_numeric(df2_trials['FINCH_ACC'])
df2_trials['FINCH_NMI'] = pd.to_numeric(df2_trials['FINCH_NMI'])

# Plot
plt.figure(figsize=(10, 6))

# ViT-B/16 finetuned
plt.plot(df1_trials['trial'], df1_trials['FINCH_ACC'], marker='o', label='Finetuned ACC')
plt.plot(df1_trials['trial'], df1_trials['FINCH_NMI'], marker='s', label='Finetuned NMI')

# ViT-B/16 non-finetuned
plt.plot(df2_trials['trial'], df2_trials['FINCH_ACC'], marker='^', label='Non-finetuned ACC')
plt.plot(df2_trials['trial'], df2_trials['FINCH_NMI'], marker='x', label='Non-finetuned NMI')

plt.xlabel('Trial')
plt.ylabel('Score')
plt.title('Perbandingan Finetuned vs Non-Finetuned ViT-B/16 (12 Labeled / 40 Unlabeled)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[57], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Load CSV pertama (finetuned)
# ----> 5 df1 = pd.read_csv(r"C:\Users\HP\novelty\notebooks\finetuned\vit_b_16\file1.csv")
#       6 df1_trials = df1[df1['trial'] != 'Average'].copy()
#       7 df1_trials['FINCH_ACC'] = pd.to_numeric(df1_trials['FINCH_ACC'])
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
