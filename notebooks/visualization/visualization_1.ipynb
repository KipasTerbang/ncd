# %% [markdown]
# 4.4.1

# %%
import matplotlib.pyplot as plt

# Contoh data ACC dari hasil clustering FINCH (ganti dengan nilai sebenarnya)
vit_b16_acc = [0.608, 0.676, 0.727, 0.765]
vit_l16_acc = [0.632, 0.687, 0.762, 0.831]

# Label konfigurasi trial (jumlah kelas berlabel)
x_labels = [
    '12 Labeled & 40 Unlabeled',
    '22 Labeled & 30 Unlabeled',
    '32 Labeled & 20 Unlabeled',
    '42 Labeled & 10 Unlabeled'
]

x = range(len(x_labels))  # posisi pada sumbu x

# Visualisasi
plt.figure(figsize=(10, 6))
plt.plot(x, vit_b16_acc, marker='o', label='ViT-B/16')
max_b16_idx = vit_b16_acc.index(max(vit_b16_acc))
plt.plot(max_b16_idx, vit_b16_acc[max_b16_idx], 'ro', label=f'ViT-B/16 Top: {vit_b16_acc[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_acc, marker='s', label='ViT-L/16')
max_l16_idx = vit_l16_acc.index(max(vit_l16_acc))
plt.plot(max_l16_idx, vit_l16_acc[max_l16_idx], 'rs', label=f'ViT-L/16 Top: {vit_l16_acc[max_l16_idx]:.3f}')

# Konfigurasi plot dengan keterangan FINCH
plt.xticks(x, x_labels, rotation=0)
plt.xlabel('Variasi Jumlah Kelas Berlabel dan Tidak Berlabel')
plt.ylabel('Rata-rata Nilai Clustering Accuracy dari Clustering FINCH')
plt.title('Perbandingan Clustering Accuracy ViT-B/16 dan ViT-L/16 yang Dilatih Ulang pada Berbagai Variasi Data\nmenggunakan Algoritma Clustering FINCH')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Contoh data NMI dari hasil clustering FINCH (ganti dengan nilai sebenarnya)
vit_b16_nmi = [0.748, 0.779, 0.832, 0.816]
vit_l16_nmi = [0.760, 0.807, 0.858, 0.876]

# Label konfigurasi trial (jumlah kelas berlabel)
x_labels = [
    '12 Labeled & 40 Unlabeled',
    '22 Labeled & 30 Unlabeled',
    '32 Labeled & 20 Unlabeled',
    '42 Labeled & 10 Unlabeled'
]

x = range(len(x_labels))  # posisi pada sumbu x

# Visualisasi
plt.figure(figsize=(10, 6))
plt.plot(x, vit_b16_nmi, marker='o', label='ViT-B/16')
max_b16_idx = vit_b16_nmi.index(max(vit_b16_nmi))
plt.plot(max_b16_idx, vit_b16_nmi[max_b16_idx], 'ro', label=f'ViT-B/16 Top: {vit_b16_nmi[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_nmi, marker='s', label='ViT-L/16')
max_l16_idx = vit_l16_nmi.index(max(vit_l16_nmi))
plt.plot(max_l16_idx, vit_l16_nmi[max_l16_idx], 'rs', label=f'ViT-L/16 Top: {vit_l16_nmi[max_l16_idx]:.3f}')

# Konfigurasi plot dengan keterangan FINCH
plt.xticks(x, x_labels, rotation=0)
plt.xlabel('Variasi Jumlah Kelas Berlabel dan Tak Berlabel')
plt.ylabel('Rata-rata Nilai NMI dari Clustering FINCH')
plt.title('Perbandingan NMI ViT-B/16 dan ViT-L/16 yang Dilatih Ulang pada Berbagai Variasi Data\nmenggunakan Algoritma Clustering FINCH')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 4.4.2

# %%
import matplotlib.pyplot as plt

# Contoh data ACC dari hasil clustering FINCH (ganti dengan nilai sebenarnya)
vit_b16_acc = [0.694, 0.711, 0.773, 0.813]
vit_l16_acc = [0.731, 0.747, 0.782, 0.780]

# Label konfigurasi trial (jumlah kelas berlabel)
x_labels = [
    '40 Unlabeled',
    '30 Unlabeled',
    '20 Unlabeled',
    '10 Unlabeled'
]

x = range(len(x_labels))  # posisi pada sumbu x

# Visualisasi
plt.figure(figsize=(10, 6))
plt.plot(x, vit_b16_acc, marker='o', label='ViT-B/16')
max_b16_idx = vit_b16_acc.index(max(vit_b16_acc))
plt.plot(max_b16_idx, vit_b16_acc[max_b16_idx], 'ro', label=f'ViT-B/16 Top: {vit_b16_acc[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_acc, marker='s', label='ViT-L/16')
max_l16_idx = vit_l16_acc.index(max(vit_l16_acc))
plt.plot(max_l16_idx, vit_l16_acc[max_l16_idx], 'rs', label=f'ViT-L/16 Top: {vit_l16_acc[max_l16_idx]:.3f}')

# Konfigurasi plot dengan keterangan FINCH
plt.xticks(x, x_labels, rotation=0)
plt.xlabel('Variasi Jumlah Kelas Tidak Berlabel')
plt.ylabel('Rata-rata Nilai Clustering Accuracy dari Clustering FINCH')
plt.title('Perbandingan Clustering Accuracy ViT-B/16 dan ViT-L/16 Pretrained pada Berbagai Variasi Data\nmenggunakan Algoritma Clustering FINCH')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Contoh data ACC dari hasil clustering FINCH (ganti dengan nilai sebenarnya)
vit_b16_acc = [0.824, 0.831, 0.868, 0.870]
vit_l16_acc = [0.858, 0.870, 0.880, 0.874]

# Label konfigurasi trial (jumlah kelas berlabel)
x_labels = [
    '40 Unlabeled',
    '30 Unlabeled',
    '20 Unlabeled',
    '10 Unlabeled'
]

x = range(len(x_labels))  # posisi pada sumbu x

# Visualisasi
plt.figure(figsize=(10, 6))
plt.plot(x, vit_b16_acc, marker='o', label='ViT-B/16')
max_b16_idx = vit_b16_acc.index(max(vit_b16_acc))
plt.plot(max_b16_idx, vit_b16_acc[max_b16_idx], 'ro', label=f'ViT-B/16 Top: {vit_b16_acc[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_acc, marker='s', label='ViT-L/16')
max_l16_idx = vit_l16_acc.index(max(vit_l16_acc))
plt.plot(max_l16_idx, vit_l16_acc[max_l16_idx], 'rs', label=f'ViT-L/16 Top: {vit_l16_acc[max_l16_idx]:.3f}')

# Konfigurasi plot dengan keterangan FINCH
plt.xticks(x, x_labels, rotation=0)
plt.xlabel('Variasi Jumlah Kelas Tidak Berlabel')
plt.ylabel('Rata-rata Nilai NMI dari Clustering FINCH')
plt.title('Perbandingan NMI ViT-B/16 dan ViT-L/16 Pretrained pada Berbagai Variasi Data\nmenggunakan Algoritma Clustering FINCH')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 4.4.3

# %%
import matplotlib.pyplot as plt

# Contoh data ACC dari hasil clustering FINCH (ganti dengan nilai sebenarnya)
vit_b16_acc = [0.575, 0.681, 0.736, 0.756]
vit_l16_acc = [0.562, 0.687, 0.706, 0.731]

vit_b16_acc_pretrained = [0.672, 0.709, 0.739, 0.798]
vit_l16_acc_pretrained = [0.684, 0.712, 0.703, 0.787]

# Label konfigurasi trial (jumlah kelas berlabel)
x_labels = [
    '12 Labeled & 40 Unlabeled',
    '22 Labeled & 30 Unlabeled',
    '32 Labeled & 20 Unlabeled',
    '42 Labeled & 10 Unlabeled'
]

x = range(len(x_labels))  # posisi pada sumbu x

# Visualisasi
plt.figure(figsize=(10, 6))
plt.plot(x, vit_b16_acc, marker='o', label='ViT-B/16(dilatih ulang)')
max_b16_idx = vit_b16_acc.index(max(vit_b16_acc))
plt.plot(max_b16_idx, vit_b16_acc[max_b16_idx], 'ro', label=f'ViT-B/16(dilatih ulang) Top: {vit_b16_acc[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_acc, marker='s', label='ViT-L/16(dilatih ulang)')
max_l16_idx = vit_l16_acc.index(max(vit_l16_acc))
plt.plot(max_l16_idx, vit_l16_acc[max_l16_idx], 'rs', label=f'ViT-L/16(dilatih ulang) Top: {vit_l16_acc[max_l16_idx]:.3f}')

plt.plot(x, vit_b16_acc_pretrained, marker='o', label='ViT-B/16(pretrained)')
max_b16_idx = vit_b16_acc_pretrained.index(max(vit_b16_acc_pretrained))
plt.plot(max_b16_idx, vit_b16_acc_pretrained[max_b16_idx], 'ro', label=f'ViT-B/16(pretrained) Top: {vit_b16_acc_pretrained[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_acc_pretrained, marker='s', color='purple', label='ViT-L/16(pretrained)')
max_l16_idx = vit_l16_acc_pretrained.index(max(vit_l16_acc_pretrained))
plt.plot(max_l16_idx, vit_l16_acc_pretrained[max_l16_idx], 'rs', label=f'ViT-L/16(pretrained) Top: {vit_l16_acc_pretrained[max_l16_idx]:.3f}')

# Konfigurasi plot dengan keterangan FINCH
plt.xticks(x, x_labels, rotation=0)
plt.xlabel('Variasi Jumlah Kelas Tidak Berlabel')
plt.ylabel('Rata-rata Nilai Clustering Accuracy dari Clustering K-Means')
plt.title('Perbandingan Clustering Accuracy ViT-B/16 dan ViT-L/16 Pretrained pada Berbagai Variasi Data\nmenggunakan Algoritma Clustering K-Means')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Contoh data ACC dari hasil clustering FINCH (ganti dengan nilai sebenarnya)
vit_b16_acc = [0.687, 0.739, 0.785, 0.742]
vit_l16_acc = [0.674, 0.729, 0.768, 0.749]

vit_b16_acc_pretrained = [0.781, 0.790, 0.825, 0.833]
vit_l16_acc_pretrained = [0.799, 0.820, 0.826, 0.841]

# Label konfigurasi trial (jumlah kelas berlabel)
x_labels = [
    '12 Labeled & 40 Unlabeled',
    '22 Labeled & 30 Unlabeled',
    '32 Labeled & 20 Unlabeled',
    '42 Labeled & 10 Unlabeled'
]

x = range(len(x_labels))  # posisi pada sumbu x

# Visualisasi
plt.figure(figsize=(10, 6))
plt.plot(x, vit_b16_acc, marker='o', label='ViT-B/16(dilatih ulang)')
max_b16_idx = vit_b16_acc.index(max(vit_b16_acc))
plt.plot(max_b16_idx, vit_b16_acc[max_b16_idx], 'ro', label=f'ViT-B/16(dilatih ulang) Top: {vit_b16_acc[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_acc, marker='s', label='ViT-L/16(dilatih ulang)')
max_l16_idx = vit_l16_acc.index(max(vit_l16_acc))
plt.plot(max_l16_idx, vit_l16_acc[max_l16_idx], 'rs', label=f'ViT-L/16(dilatih ulang) Top: {vit_l16_acc[max_l16_idx]:.3f}')

plt.plot(x, vit_b16_acc_pretrained, marker='o', label='ViT-B/16(pretrained)')
max_b16_idx = vit_b16_acc_pretrained.index(max(vit_b16_acc_pretrained))
plt.plot(max_b16_idx, vit_b16_acc_pretrained[max_b16_idx], 'ro', label=f'ViT-B/16(pretrained) Top: {vit_b16_acc_pretrained[max_b16_idx]:.3f}')

plt.plot(x, vit_l16_acc_pretrained, marker='s', color='purple', label='ViT-L/16(pretrained)')
max_l16_idx = vit_l16_acc_pretrained.index(max(vit_l16_acc_pretrained))
plt.plot(max_l16_idx, vit_l16_acc_pretrained[max_l16_idx], 'rs', label=f'ViT-L/16(pretrained) Top: {vit_l16_acc_pretrained[max_l16_idx]:.3f}')

# Konfigurasi plot dengan keterangan FINCH
plt.xticks(x, x_labels, rotation=0)
plt.xlabel('Variasi Jumlah Kelas Tidak Berlabel')
plt.ylabel('Rata-rata Nilai NMI dari Clustering K-Means')
plt.title('Perbandingan NMI ViT-B/16 dan ViT-L/16 Pretrained pada Berbagai Variasi Data\nmenggunakan Algoritma Clustering K-Means')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
