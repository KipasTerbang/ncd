# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import torchvision.transforms as transforms
from torchvision.models import vit_l_16, ViT_L_16_Weights
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
from sklearn.metrics import normalized_mutual_info_score
from sklearn.cluster import KMeans
from scipy.optimize import linear_sum_assignment
from finch import FINCH
from tqdm import tqdm

# ======================== DEVICE ========================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ======================== VIT FEATURE EXTRACTOR ========================
class ViTFeatureExtractor(nn.Module):
    def __init__(self):
        super(ViTFeatureExtractor, self).__init__()
        self.backbone = vit_l_16(weights=ViT_L_16_Weights.IMAGENET1K_V1)
        for param in self.backbone.parameters():
            param.requires_grad = False
        self.backbone.heads = nn.Identity()

    def forward(self, x):
        return self.backbone(x)

model = ViTFeatureExtractor().to(device)

# ======================== EKSTRAK FITUR & SIMPAN ========================
def extract_features_to_file(model, data_loader, save_path):
    model.eval()
    final_list = []
    with torch.no_grad():
        for images, labels in tqdm(data_loader):
            images = images.to(device)
            features = model(images).cpu().numpy()
            labels = labels.numpy()
            for feat, label in zip(features, labels):
                final_list.append([feat, label])
    np.save(save_path, np.array(final_list, dtype=object))

# ======================== CLUSTERING METRIK ========================
def clustering_accuracy(y_true, y_pred):
    D = max(y_pred.max(), y_true.max()) + 1
    w = np.zeros((D, D), dtype=np.int64)
    for i in range(y_pred.size):
        w[y_pred[i], y_true[i]] += 1
    row_ind, col_ind = linear_sum_assignment(w.max() - w)
    return w[row_ind, col_ind].sum() / y_pred.size

# ======================== FITUR EKSTRAKSI DARI CLASSIFIER ========================
def extract_features(loader, model):
    model.eval()
    all_feats, all_labels = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            feat = model.getHidden(x).cpu().numpy()
            all_feats.append(feat)
            all_labels.append(y.numpy())
    return np.concatenate(all_feats), np.concatenate(all_labels)

# ======================== DATASET FITUR ========================
class FeatureDataset(Dataset):
    def __init__(self, data):
        self.features = [item[0] for item in data]
        self.labels = [item[1] for item in data]

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return torch.tensor(self.features[idx], dtype=torch.float32), torch.tensor(self.labels[idx], dtype=torch.long)

# ======================== SIMPLE CLASSIFIER ========================
class SimpleClassifier(nn.Module):
    def __init__(self, input_dim=1024, hidden_dim=4096, num_classes=12):
        super(SimpleClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        return self.model(x)

    def getHidden(self, x):
        x = self.model[0](x)
        return x

# ======================== LOOP TRIAL ========================
results_final = []

for trial in range(5):
    # Transforms
    labeled_transform = transforms.Compose([
        transforms.RandAugment(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])
    unlabeled_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])

    # Dataset
    labeled_folder = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\32labeled_20unlabeled\labeled"
    unlabeled_folder = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\32labeled_20unlabeled\unlabeled"

    labeled_dataset = ImageFolder(root=labeled_folder, transform=labeled_transform)
    unlabeled_dataset = ImageFolder(root=unlabeled_folder, transform=unlabeled_transform)

    batch_size = 16
    labeled_loader_raw = DataLoader(labeled_dataset, batch_size=batch_size, shuffle=True)
    unlabeled_loader_raw = DataLoader(unlabeled_dataset, batch_size=batch_size, shuffle=False)

    # Ekstraksi fitur
    labeled_feat_path = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\32labeled_20unlabeled\labeled_features_vit_l_16_32labeled_20unlabeled.npy"
    unlabeled_feat_path = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\32labeled_20unlabeled\unlabeled_features_vit_l_16_32labeled_20unlabeled.npy"

    # extract_features_to_file(model, labeled_loader_raw, labeled_feat_path)
    # extract_features_to_file(model, unlabeled_loader_raw, unlabeled_feat_path)

    labeled_data = np.load(labeled_feat_path, allow_pickle=True)
    unlabeled_data = np.load(unlabeled_feat_path, allow_pickle=True)

    labeled_loader = DataLoader(FeatureDataset(labeled_data), batch_size=batch_size, shuffle=True)
    unlabeled_loader = DataLoader(FeatureDataset(unlabeled_data), batch_size=batch_size, shuffle=False)

    # Classifier setup
    num_classes = len(set([l[1] for l in labeled_data]))
    classifier = SimpleClassifier(input_dim=1024, hidden_dim=4096, num_classes=num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-3)

    results = []
    finch_partitions = []
    all_image_info = []

    for epoch in range(50):
        classifier.train()
        running_loss = 0.0

        for x, y in labeled_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            output = classifier(x)
            loss = criterion(output, y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(labeled_loader)
        print(f"Epoch {epoch+1} | Train Loss: {train_loss:.4f}")

        feats, true_labels = extract_features(unlabeled_loader, classifier)

        # FINCH clustering
        c, num_clust, _ = FINCH(feats, use_ann_above_samples=1000, verbose=True)
        partition_info = {"Epoch": epoch + 1}
        for i, clust in enumerate(num_clust):
            partition_info[f"Partition {i}"] = clust
        finch_partitions.append(partition_info)

        finch_clusters = c[:, 2]
        finch_nmi = normalized_mutual_info_score(true_labels, finch_clusters)
        finch_acc = clustering_accuracy(true_labels, finch_clusters)

        # KMeans clustering
        num_clusters = len(np.unique(true_labels))
        kmeans = KMeans(n_clusters=num_clusters, random_state=42).fit(feats)
        kmeans_clusters = kmeans.labels_
        kmeans_nmi = normalized_mutual_info_score(true_labels, kmeans_clusters)
        kmeans_acc = clustering_accuracy(true_labels, kmeans_clusters)

        print(f"FINCH ACC: {finch_acc:.4f} | NMI: {finch_nmi:.4f} | Clusters: {len(np.unique(finch_clusters))}")
        print(f"KMeans ACC: {kmeans_acc:.4f} | NMI: {kmeans_nmi:.4f} | Clusters: {len(np.unique(kmeans_clusters))}\n")

        results.append({
            "Epoch": epoch + 1,
            "Loss": train_loss,
            "FINCH_ACC": finch_acc,
            "FINCH_NMI": finch_nmi,
            "FINCH_Clusters": len(np.unique(finch_clusters)),
            "KMeans_ACC": kmeans_acc,
            "KMeans_NMI": kmeans_nmi,
            "KMeans_Clusters": len(np.unique(kmeans_clusters))
        })

    unlabeled_features, unlabeled_true_labels = extract_features(unlabeled_loader, classifier)
    
    c, num_clust, req_c = FINCH(unlabeled_features, use_ann_above_samples=1000, verbose=True)
    finch_clusters = c[:,2]

    finch_nmi = normalized_mutual_info_score(unlabeled_true_labels, finch_clusters)
    finch_acc = clustering_accuracy(unlabeled_true_labels, finch_clusters)

    print(f"\nFINCH Clustering Performance:")
    print(f"Clustering Accuracy (ACC): {finch_acc:.4f}")
    print(f"Normalized Mutual Information (NMI): {finch_nmi:.4f}")
    print(f"Number of clusters found: {len(np.unique(finch_clusters))}")
    
    num_clusters = len(np.unique(unlabeled_true_labels))
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans_clusters = kmeans.fit_predict(unlabeled_features)

    # ----- Evaluasi -----
    kmeans_nmi = normalized_mutual_info_score(unlabeled_true_labels, kmeans_clusters)
    kmeans_acc = clustering_accuracy(unlabeled_true_labels, kmeans_clusters)

    print(f"\nK-Means Clustering Performance: {num_clusters} Clusters")
    print(f"Clustering Accuracy (ACC): {kmeans_acc:.4f}")
    print(f"Normalized Mutual Information (NMI): {kmeans_nmi:.4f}")
    print(f"Number of clusters found: {len(np.unique(kmeans_clusters))}")
    
    # Simpan hasil trial ini
    results_final.append({
        'trial': trial,
        'FINCH_ACC': finch_acc,
        'FINCH_NMI': finch_nmi,
        'FINCH_Num_Clusters': len(np.unique(finch_clusters)),
        'KMeans_ACC': kmeans_acc,
        'KMeans_NMI': kmeans_nmi,
        'KMeans_Num_Clusters': len(np.unique(kmeans_clusters)),
    })
    
    # Simpan hasil per gambar
    for i in range(len(unlabeled_dataset)):
        path, true_label = unlabeled_dataset.samples[i]
        image_info = {
            'trial': trial,
            'image_path': path,
            'true_label': true_label,
            'finch_cluster': int(finch_clusters[i]),
            'kmeans_cluster': int(kmeans_clusters[i])
        }
        all_image_info.append(image_info)

    # Simpan file CSV per trial
    df_trial_detail = pd.DataFrame(all_image_info[-len(unlabeled_dataset):])  # ambil data dari trial ini saja
    df_trial_detail.to_csv(f'vit_l_16_finetuned_32labeled_20unlabeled_trial_{trial}_image_clustering.csv', index=False)

    # Simpan hasil
    result_csv = fr"clustering_metrics_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_{trial}.csv"
    partition_csv = fr"finch_partitions_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_{trial}.csv"

    pd.DataFrame(results).to_csv(result_csv, index=False)
    pd.DataFrame(finch_partitions).to_csv(partition_csv, index=False)

    print(f"\n📄 Hasil clustering disimpan di: {result_csv}")
    print(f"📄 Partisi FINCH disimpan di: {partition_csv}")

df_results = pd.DataFrame(results_final)
mean_values = df_results.select_dtypes(include=np.number).mean()

mean_row = pd.DataFrame({
    'trial': ['Average'],
    'FINCH_ACC': [mean_values['FINCH_ACC']],
    'FINCH_NMI': [mean_values['FINCH_NMI']],
    'FINCH_Num_Clusters': [mean_values['FINCH_Num_Clusters']],
    'KMeans_ACC': [mean_values['KMeans_ACC']],
    'KMeans_NMI': [mean_values['KMeans_NMI']],
    'KMeans_Num_Clusters': [mean_values['KMeans_Num_Clusters']]
})

df_results = pd.concat([df_results, mean_row], ignore_index=True)

df_results.to_csv('clustering_results_vit_l_16_finetuned_32labeled_20unlabeled_FINCH_KMEANS.csv', index=False)
print("Results saved to clustering_results_vit_l_16_finetuned_32labeled_20unlabeled_FINCH_KMEANS.csv")
# Out:
# Epoch 1 | Train Loss: 0.4683
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 420 clusters
# Partition 1: 88 clusters
# Partition 2: 22 clusters
# Partition 3: 5 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7360 | NMI: 0.8224 | Clusters: 22
# KMeans ACC: 0.6445 | NMI: 0.7448 | Clusters: 20
#
# Epoch 2 | Train Loss: 0.0717
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 89 clusters
# Partition 2: 23 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7715 | NMI: 0.8294 | Clusters: 23
# KMeans ACC: 0.6945 | NMI: 0.7595 | Clusters: 20
#
# Epoch 3 | Train Loss: 0.0427
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 99 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7685 | NMI: 0.8400 | Clusters: 25
# KMeans ACC: 0.7315 | NMI: 0.7916 | Clusters: 20
#
# Epoch 4 | Train Loss: 0.1169
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 423 clusters
# Partition 1: 101 clusters
# Partition 2: 23 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6880 | NMI: 0.8113 | Clusters: 23
# KMeans ACC: 0.6830 | NMI: 0.7477 | Clusters: 20
#
# Epoch 5 | Train Loss: 0.1598
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 92 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7155 | NMI: 0.8049 | Clusters: 21
# KMeans ACC: 0.6330 | NMI: 0.7150 | Clusters: 20
#
# Epoch 6 | Train Loss: 0.0802
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 100 clusters
# Partition 2: 19 clusters
# Partition 3: 5 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7285 | NMI: 0.8185 | Clusters: 19
# KMeans ACC: 0.7560 | NMI: 0.7655 | Clusters: 20
#
# Epoch 7 | Train Loss: 0.0740
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 98 clusters
# Partition 2: 20 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7370 | NMI: 0.8131 | Clusters: 20
# KMeans ACC: 0.7025 | NMI: 0.7400 | Clusters: 20
#
# Epoch 8 | Train Loss: 0.0266
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 91 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.6825 | NMI: 0.7937 | Clusters: 21
# KMeans ACC: 0.7190 | NMI: 0.7517 | Clusters: 20
#
# Epoch 9 | Train Loss: 0.0240
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 100 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7255 | NMI: 0.8281 | Clusters: 20
# KMeans ACC: 0.7395 | NMI: 0.7474 | Clusters: 20
#
# Epoch 10 | Train Loss: 0.0027
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 90 clusters
# Partition 2: 18 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7280 | NMI: 0.8007 | Clusters: 18
# KMeans ACC: 0.6835 | NMI: 0.7414 | Clusters: 20
#
# Epoch 11 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 96 clusters
# Partition 2: 18 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7515 | NMI: 0.8007 | Clusters: 18
# KMeans ACC: 0.7270 | NMI: 0.7590 | Clusters: 20
#
# Epoch 12 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 98 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7735 | NMI: 0.8096 | Clusters: 21
# KMeans ACC: 0.7270 | NMI: 0.7590 | Clusters: 20
#
# Epoch 13 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 96 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7485 | NMI: 0.8144 | Clusters: 21
# KMeans ACC: 0.6790 | NMI: 0.7422 | Clusters: 20
#
# Epoch 14 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 91 clusters
# Partition 2: 18 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7340 | NMI: 0.8038 | Clusters: 18
# KMeans ACC: 0.6785 | NMI: 0.7418 | Clusters: 20
#
# Epoch 15 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 99 clusters
# Partition 2: 23 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7210 | NMI: 0.8111 | Clusters: 23
# KMeans ACC: 0.6790 | NMI: 0.7421 | Clusters: 20
#
# Epoch 16 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 98 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7280 | NMI: 0.8149 | Clusters: 21
# KMeans ACC: 0.6790 | NMI: 0.7421 | Clusters: 20
#
# Epoch 17 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 95 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7505 | NMI: 0.8311 | Clusters: 20
# KMeans ACC: 0.6785 | NMI: 0.7419 | Clusters: 20
#
# Epoch 18 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 95 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7440 | NMI: 0.8157 | Clusters: 21
# KMeans ACC: 0.6785 | NMI: 0.7419 | Clusters: 20
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 99 clusters
# Partition 2: 20 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7405 | NMI: 0.8185 | Clusters: 20
# KMeans ACC: 0.6970 | NMI: 0.7435 | Clusters: 20
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 91 clusters
# Partition 2: 19 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7330 | NMI: 0.8088 | Clusters: 19
# KMeans ACC: 0.6970 | NMI: 0.7435 | Clusters: 20
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 95 clusters
# Partition 2: 22 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7365 | NMI: 0.8089 | Clusters: 22
# KMeans ACC: 0.6970 | NMI: 0.7435 | Clusters: 20
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 97 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7300 | NMI: 0.8316 | Clusters: 20
# KMeans ACC: 0.6980 | NMI: 0.7451 | Clusters: 20
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 94 clusters
# Partition 2: 20 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.6950 | NMI: 0.7943 | Clusters: 20
# KMeans ACC: 0.6980 | NMI: 0.7450 | Clusters: 20
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 98 clusters
# Partition 2: 22 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7020 | NMI: 0.8057 | Clusters: 22
# KMeans ACC: 0.6965 | NMI: 0.7435 | Clusters: 20
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 96 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7250 | NMI: 0.7978 | Clusters: 20
# KMeans ACC: 0.6950 | NMI: 0.7507 | Clusters: 20
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 93 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7330 | NMI: 0.7967 | Clusters: 21
# KMeans ACC: 0.6945 | NMI: 0.7497 | Clusters: 20
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 98 clusters
# Partition 2: 21 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.6930 | NMI: 0.8048 | Clusters: 21
# KMeans ACC: 0.6945 | NMI: 0.7497 | Clusters: 20
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 427 clusters
# Partition 1: 90 clusters
# Partition 2: 21 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.6895 | NMI: 0.8102 | Clusters: 21
# KMeans ACC: 0.6945 | NMI: 0.7497 | Clusters: 20
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 93 clusters
# Partition 2: 18 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7220 | NMI: 0.8051 | Clusters: 18
# KMeans ACC: 0.7470 | NMI: 0.7571 | Clusters: 20
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 429 clusters
# Partition 1: 96 clusters
# Partition 2: 18 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7060 | NMI: 0.8015 | Clusters: 18
# KMeans ACC: 0.7470 | NMI: 0.7566 | Clusters: 20
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 96 clusters
# Partition 2: 21 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7620 | NMI: 0.8303 | Clusters: 21
# KMeans ACC: 0.7470 | NMI: 0.7566 | Clusters: 20
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 94 clusters
# Partition 2: 19 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.6870 | NMI: 0.7842 | Clusters: 19
# KMeans ACC: 0.7470 | NMI: 0.7566 | Clusters: 20
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 91 clusters
# Partition 2: 19 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7610 | NMI: 0.8095 | Clusters: 19
# KMeans ACC: 0.7450 | NMI: 0.7569 | Clusters: 20
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 96 clusters
# Partition 2: 22 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7545 | NMI: 0.8083 | Clusters: 22
# KMeans ACC: 0.7480 | NMI: 0.7553 | Clusters: 20
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 94 clusters
# Partition 2: 17 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7395 | NMI: 0.8190 | Clusters: 17
# KMeans ACC: 0.7525 | NMI: 0.7570 | Clusters: 20
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 429 clusters
# Partition 1: 96 clusters
# Partition 2: 22 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7165 | NMI: 0.8064 | Clusters: 22
# KMeans ACC: 0.7500 | NMI: 0.7577 | Clusters: 20
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 99 clusters
# Partition 2: 21 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7135 | NMI: 0.8002 | Clusters: 21
# KMeans ACC: 0.7510 | NMI: 0.7586 | Clusters: 20
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 429 clusters
# Partition 1: 97 clusters
# Partition 2: 21 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7680 | NMI: 0.8144 | Clusters: 21
# KMeans ACC: 0.7510 | NMI: 0.7586 | Clusters: 20
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 100 clusters
# Partition 2: 24 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6925 | NMI: 0.8093 | Clusters: 24
# KMeans ACC: 0.7510 | NMI: 0.7586 | Clusters: 20
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 99 clusters
# Partition 2: 23 clusters
# Partition 3: 5 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7090 | NMI: 0.8084 | Clusters: 23
# KMeans ACC: 0.6740 | NMI: 0.7462 | Clusters: 20
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 428 clusters
# Partition 1: 99 clusters
# Partition 2: 21 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7735 | NMI: 0.8358 | Clusters: 21
# KMeans ACC: 0.6740 | NMI: 0.7468 | Clusters: 20
#
# Epoch 42 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 89 clusters
# Partition 2: 19 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.6910 | NMI: 0.8088 | Clusters: 19
# KMeans ACC: 0.6715 | NMI: 0.7430 | Clusters: 20
#
# Epoch 43 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 426 clusters
# Partition 1: 95 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7700 | NMI: 0.8152 | Clusters: 20
# KMeans ACC: 0.6715 | NMI: 0.7430 | Clusters: 20
#
# Epoch 44 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 429 clusters
# Partition 1: 100 clusters
# Partition 2: 20 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7665 | NMI: 0.8238 | Clusters: 20
# KMeans ACC: 0.6715 | NMI: 0.7436 | Clusters: 20
#
# Epoch 45 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 92 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7600 | NMI: 0.8209 | Clusters: 20
# KMeans ACC: 0.6710 | NMI: 0.7431 | Clusters: 20
#
# Epoch 46 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 95 clusters
# Partition 2: 19 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7610 | NMI: 0.8288 | Clusters: 19
# KMeans ACC: 0.6690 | NMI: 0.7427 | Clusters: 20
#
# Epoch 47 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 97 clusters
# Partition 2: 22 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7060 | NMI: 0.8134 | Clusters: 22
# KMeans ACC: 0.7230 | NMI: 0.7431 | Clusters: 20
#
# Epoch 48 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 98 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.7090 | NMI: 0.7907 | Clusters: 20
# KMeans ACC: 0.7200 | NMI: 0.7426 | Clusters: 20
#
# Epoch 49 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 427 clusters
# Partition 1: 97 clusters
# Partition 2: 20 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.6875 | NMI: 0.8048 | Clusters: 20
# KMeans ACC: 0.7200 | NMI: 0.7423 | Clusters: 20
#
# Epoch 50 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 427 clusters
# Partition 1: 98 clusters
# Partition 2: 20 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7245 | NMI: 0.8007 | Clusters: 20
# KMeans ACC: 0.7200 | NMI: 0.7423 | Clusters: 20
#
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 99 clusters
# Partition 2: 22 clusters
# Partition 3: 5 clusters
#
# FINCH Clustering Performance:
# Clustering Accuracy (ACC): 0.7480
# Normalized Mutual Information (NMI): 0.8169
# Number of clusters found: 22
#
# K-Means Clustering Performance: 20 Clusters
# Clustering Accuracy (ACC): 0.7200
# Normalized Mutual Information (NMI): 0.7423
# Number of clusters found: 20
#
# 📄 Hasil clustering disimpan di: clustering_metrics_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_0.csv
# 📄 Partisi FINCH disimpan di: finch_partitions_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_0.csv
# Epoch 1 | Train Loss: 0.4821
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 442 clusters
# Partition 1: 96 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7845 | NMI: 0.8630 | Clusters: 26
# KMeans ACC: 0.7890 | NMI: 0.8241 | Clusters: 20
#
# Epoch 2 | Train Loss: 0.1048
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 455 clusters
# Partition 1: 98 clusters
# Partition 2: 24 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7950 | NMI: 0.8672 | Clusters: 24
# KMeans ACC: 0.7955 | NMI: 0.8388 | Clusters: 20
#
# Epoch 3 | Train Loss: 0.0793
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 451 clusters
# Partition 1: 102 clusters
# Partition 2: 23 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7575 | NMI: 0.8576 | Clusters: 23
# KMeans ACC: 0.7375 | NMI: 0.8112 | Clusters: 20
#
# Epoch 4 | Train Loss: 0.0508
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 446 clusters
# Partition 1: 94 clusters
# Partition 2: 21 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7095 | NMI: 0.8396 | Clusters: 21
# KMeans ACC: 0.7390 | NMI: 0.8126 | Clusters: 20
#
# Epoch 5 | Train Loss: 0.0768
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 445 clusters
# Partition 1: 94 clusters
# Partition 2: 21 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.6960 | NMI: 0.8306 | Clusters: 21
# KMeans ACC: 0.6950 | NMI: 0.7979 | Clusters: 20
#
# Epoch 6 | Train Loss: 0.1148
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 456 clusters
# Partition 1: 96 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7040 | NMI: 0.8240 | Clusters: 26
# KMeans ACC: 0.7135 | NMI: 0.7882 | Clusters: 20
#
# Epoch 7 | Train Loss: 0.0991
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 455 clusters
# Partition 1: 99 clusters
# Partition 2: 27 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7110 | NMI: 0.8511 | Clusters: 27
# KMeans ACC: 0.7135 | NMI: 0.7797 | Clusters: 20
#
# Epoch 8 | Train Loss: 0.0702
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 95 clusters
# Partition 2: 28 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.7620 | NMI: 0.8733 | Clusters: 28
# KMeans ACC: 0.7470 | NMI: 0.7981 | Clusters: 20
#
# Epoch 9 | Train Loss: 0.0416
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 428 clusters
# Partition 1: 85 clusters
# Partition 2: 22 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7600 | NMI: 0.8598 | Clusters: 22
# KMeans ACC: 0.7000 | NMI: 0.7839 | Clusters: 20
#
# Epoch 10 | Train Loss: 0.0229
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 94 clusters
# Partition 2: 24 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7645 | NMI: 0.8608 | Clusters: 24
# KMeans ACC: 0.7315 | NMI: 0.7800 | Clusters: 20
#
# Epoch 11 | Train Loss: 0.0606
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 88 clusters
# Partition 2: 27 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7090 | NMI: 0.8576 | Clusters: 27
# KMeans ACC: 0.7415 | NMI: 0.7997 | Clusters: 20
#
# Epoch 12 | Train Loss: 0.1066
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 94 clusters
# Partition 2: 24 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7685 | NMI: 0.8584 | Clusters: 24
# KMeans ACC: 0.6740 | NMI: 0.7693 | Clusters: 20
#
# Epoch 13 | Train Loss: 0.0835
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 86 clusters
# Partition 2: 24 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.8010 | NMI: 0.8731 | Clusters: 24
# KMeans ACC: 0.7165 | NMI: 0.7955 | Clusters: 20
#
# Epoch 14 | Train Loss: 0.0422
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 442 clusters
# Partition 1: 89 clusters
# Partition 2: 24 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7880 | NMI: 0.8647 | Clusters: 24
# KMeans ACC: 0.7175 | NMI: 0.7842 | Clusters: 20
#
# Epoch 15 | Train Loss: 0.0149
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 80 clusters
# Partition 2: 23 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7685 | NMI: 0.8661 | Clusters: 23
# KMeans ACC: 0.6540 | NMI: 0.7578 | Clusters: 20
#
# Epoch 16 | Train Loss: 0.0425
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 97 clusters
# Partition 2: 25 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7515 | NMI: 0.8672 | Clusters: 25
# KMeans ACC: 0.6845 | NMI: 0.7744 | Clusters: 20
#
# Epoch 17 | Train Loss: 0.0100
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 85 clusters
# Partition 2: 23 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7675 | NMI: 0.8591 | Clusters: 23
# KMeans ACC: 0.7070 | NMI: 0.7878 | Clusters: 20
#
# Epoch 18 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 90 clusters
# Partition 2: 24 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7595 | NMI: 0.8740 | Clusters: 24
# KMeans ACC: 0.7375 | NMI: 0.7848 | Clusters: 20
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 91 clusters
# Partition 2: 27 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7345 | NMI: 0.8638 | Clusters: 27
# KMeans ACC: 0.7375 | NMI: 0.7848 | Clusters: 20
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 89 clusters
# Partition 2: 22 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7005 | NMI: 0.8654 | Clusters: 22
# KMeans ACC: 0.7375 | NMI: 0.7848 | Clusters: 20
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 442 clusters
# Partition 1: 92 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7520 | NMI: 0.8599 | Clusters: 26
# KMeans ACC: 0.7365 | NMI: 0.7835 | Clusters: 20
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 95 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.8120 | NMI: 0.8791 | Clusters: 25
# KMeans ACC: 0.7370 | NMI: 0.7833 | Clusters: 20
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 93 clusters
# Partition 2: 23 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7850 | NMI: 0.8732 | Clusters: 23
# KMeans ACC: 0.7360 | NMI: 0.7833 | Clusters: 20
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 89 clusters
# Partition 2: 24 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7785 | NMI: 0.8655 | Clusters: 24
# KMeans ACC: 0.7360 | NMI: 0.7833 | Clusters: 20
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 90 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7930 | NMI: 0.8671 | Clusters: 25
# KMeans ACC: 0.7370 | NMI: 0.7833 | Clusters: 20
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 88 clusters
# Partition 2: 24 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7895 | NMI: 0.8800 | Clusters: 24
# KMeans ACC: 0.7370 | NMI: 0.7833 | Clusters: 20
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 442 clusters
# Partition 1: 98 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7675 | NMI: 0.8613 | Clusters: 26
# KMeans ACC: 0.7370 | NMI: 0.7833 | Clusters: 20
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 93 clusters
# Partition 2: 27 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7770 | NMI: 0.8666 | Clusters: 27
# KMeans ACC: 0.7370 | NMI: 0.7833 | Clusters: 20
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 89 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.8120 | NMI: 0.8784 | Clusters: 25
# KMeans ACC: 0.7370 | NMI: 0.7833 | Clusters: 20
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 89 clusters
# Partition 2: 21 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7880 | NMI: 0.8737 | Clusters: 21
# KMeans ACC: 0.7370 | NMI: 0.7833 | Clusters: 20
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 90 clusters
# Partition 2: 22 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7415 | NMI: 0.8643 | Clusters: 22
# KMeans ACC: 0.7360 | NMI: 0.7837 | Clusters: 20
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 92 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7765 | NMI: 0.8681 | Clusters: 26
# KMeans ACC: 0.7360 | NMI: 0.7837 | Clusters: 20
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 89 clusters
# Partition 2: 26 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7790 | NMI: 0.8686 | Clusters: 26
# KMeans ACC: 0.7360 | NMI: 0.7837 | Clusters: 20
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 90 clusters
# Partition 2: 22 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7780 | NMI: 0.8745 | Clusters: 22
# KMeans ACC: 0.7360 | NMI: 0.7837 | Clusters: 20
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 93 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7725 | NMI: 0.8633 | Clusters: 25
# KMeans ACC: 0.7360 | NMI: 0.7837 | Clusters: 20
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 97 clusters
# Partition 2: 25 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7905 | NMI: 0.8698 | Clusters: 25
# KMeans ACC: 0.7360 | NMI: 0.7837 | Clusters: 20
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 92 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7610 | NMI: 0.8724 | Clusters: 26
# KMeans ACC: 0.7355 | NMI: 0.7823 | Clusters: 20
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 93 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7875 | NMI: 0.8713 | Clusters: 25
# KMeans ACC: 0.7355 | NMI: 0.7823 | Clusters: 20
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 92 clusters
# Partition 2: 20 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7935 | NMI: 0.8740 | Clusters: 20
# KMeans ACC: 0.7355 | NMI: 0.7824 | Clusters: 20
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 89 clusters
# Partition 2: 24 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.8140 | NMI: 0.8734 | Clusters: 24
# KMeans ACC: 0.7355 | NMI: 0.7824 | Clusters: 20
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 444 clusters
# Partition 1: 90 clusters
# Partition 2: 23 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7910 | NMI: 0.8735 | Clusters: 23
# KMeans ACC: 0.7370 | NMI: 0.7834 | Clusters: 20
#
# Epoch 42 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 91 clusters
# Partition 2: 25 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7975 | NMI: 0.8724 | Clusters: 25
# KMeans ACC: 0.7370 | NMI: 0.7834 | Clusters: 20
#
# Epoch 43 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 92 clusters
# Partition 2: 24 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7825 | NMI: 0.8811 | Clusters: 24
# KMeans ACC: 0.7370 | NMI: 0.7834 | Clusters: 20
#
# Epoch 44 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 87 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7580 | NMI: 0.8619 | Clusters: 26
# KMeans ACC: 0.7770 | NMI: 0.8005 | Clusters: 20
#
# Epoch 45 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 93 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7585 | NMI: 0.8565 | Clusters: 26
# KMeans ACC: 0.7770 | NMI: 0.8005 | Clusters: 20
#
# Epoch 46 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 91 clusters
# Partition 2: 23 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7550 | NMI: 0.8530 | Clusters: 23
# KMeans ACC: 0.7770 | NMI: 0.8005 | Clusters: 20
#
# Epoch 47 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 90 clusters
# Partition 2: 23 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7545 | NMI: 0.8637 | Clusters: 23
# KMeans ACC: 0.7305 | NMI: 0.7808 | Clusters: 20
#
# Epoch 48 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 95 clusters
# Partition 2: 26 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7940 | NMI: 0.8744 | Clusters: 26
# KMeans ACC: 0.7305 | NMI: 0.7808 | Clusters: 20
#
# Epoch 49 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 96 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7565 | NMI: 0.8720 | Clusters: 25
# KMeans ACC: 0.7310 | NMI: 0.7818 | Clusters: 20
#
# Epoch 50 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 90 clusters
# Partition 2: 26 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7600 | NMI: 0.8653 | Clusters: 26
# KMeans ACC: 0.7310 | NMI: 0.7818 | Clusters: 20
#
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 442 clusters
# Partition 1: 88 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
#
# FINCH Clustering Performance:
# Clustering Accuracy (ACC): 0.7920
# Normalized Mutual Information (NMI): 0.8732
# Number of clusters found: 25
#
# K-Means Clustering Performance: 20 Clusters
# Clustering Accuracy (ACC): 0.7310
# Normalized Mutual Information (NMI): 0.7818
# Number of clusters found: 20
#
# 📄 Hasil clustering disimpan di: clustering_metrics_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_1.csv
# 📄 Partisi FINCH disimpan di: finch_partitions_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_1.csv
# Epoch 1 | Train Loss: 0.5338
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 417 clusters
# Partition 1: 89 clusters
# Partition 2: 22 clusters
# Partition 3: 5 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.8440 | NMI: 0.8833 | Clusters: 22
# KMeans ACC: 0.7385 | NMI: 0.8282 | Clusters: 20
#
# Epoch 2 | Train Loss: 0.1012
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 96 clusters
# Partition 2: 22 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.8700 | NMI: 0.9030 | Clusters: 22
# KMeans ACC: 0.8020 | NMI: 0.8518 | Clusters: 20
#
# Epoch 3 | Train Loss: 0.0772
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 92 clusters
# Partition 2: 26 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8390 | NMI: 0.8955 | Clusters: 26
# KMeans ACC: 0.8030 | NMI: 0.8545 | Clusters: 20
#
# Epoch 4 | Train Loss: 0.0710
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 429 clusters
# Partition 1: 91 clusters
# Partition 2: 22 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8095 | NMI: 0.8829 | Clusters: 22
# KMeans ACC: 0.8085 | NMI: 0.8250 | Clusters: 20
#
# Epoch 5 | Train Loss: 0.1170
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 428 clusters
# Partition 1: 85 clusters
# Partition 2: 26 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7565 | NMI: 0.8658 | Clusters: 26
# KMeans ACC: 0.7640 | NMI: 0.8018 | Clusters: 20
#
# Epoch 6 | Train Loss: 0.0862
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 91 clusters
# Partition 2: 27 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7770 | NMI: 0.8754 | Clusters: 27
# KMeans ACC: 0.7265 | NMI: 0.7857 | Clusters: 20
#
# Epoch 7 | Train Loss: 0.0817
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 423 clusters
# Partition 1: 96 clusters
# Partition 2: 25 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.7415 | NMI: 0.8676 | Clusters: 25
# KMeans ACC: 0.7590 | NMI: 0.8069 | Clusters: 20
#
# Epoch 8 | Train Loss: 0.0871
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 421 clusters
# Partition 1: 92 clusters
# Partition 2: 24 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8635 | NMI: 0.8973 | Clusters: 24
# KMeans ACC: 0.8065 | NMI: 0.8072 | Clusters: 20
#
# Epoch 9 | Train Loss: 0.0449
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 99 clusters
# Partition 2: 27 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8230 | NMI: 0.8962 | Clusters: 27
# KMeans ACC: 0.6865 | NMI: 0.7818 | Clusters: 20
#
# Epoch 10 | Train Loss: 0.0108
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 95 clusters
# Partition 2: 23 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8485 | NMI: 0.8892 | Clusters: 23
# KMeans ACC: 0.7255 | NMI: 0.7922 | Clusters: 20
#
# Epoch 11 | Train Loss: 0.0138
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 96 clusters
# Partition 2: 24 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.8485 | NMI: 0.8919 | Clusters: 24
# KMeans ACC: 0.7465 | NMI: 0.7975 | Clusters: 20
#
# Epoch 12 | Train Loss: 0.1397
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 430 clusters
# Partition 1: 93 clusters
# Partition 2: 26 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8175 | NMI: 0.8854 | Clusters: 26
# KMeans ACC: 0.8015 | NMI: 0.7937 | Clusters: 20
#
# Epoch 13 | Train Loss: 0.1302
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 421 clusters
# Partition 1: 90 clusters
# Partition 2: 25 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8050 | NMI: 0.8836 | Clusters: 25
# KMeans ACC: 0.7925 | NMI: 0.7879 | Clusters: 20
#
# Epoch 14 | Train Loss: 0.1153
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 87 clusters
# Partition 2: 28 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8190 | NMI: 0.8877 | Clusters: 28
# KMeans ACC: 0.7550 | NMI: 0.7832 | Clusters: 20
#
# Epoch 15 | Train Loss: 0.0070
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 429 clusters
# Partition 1: 95 clusters
# Partition 2: 27 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7900 | NMI: 0.8807 | Clusters: 27
# KMeans ACC: 0.7245 | NMI: 0.7772 | Clusters: 20
#
# Epoch 16 | Train Loss: 0.0115
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 94 clusters
# Partition 2: 27 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7860 | NMI: 0.8721 | Clusters: 27
# KMeans ACC: 0.7145 | NMI: 0.7756 | Clusters: 20
#
# Epoch 17 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 88 clusters
# Partition 2: 22 clusters
# Partition 3: 2 clusters
# FINCH ACC: 0.8025 | NMI: 0.8843 | Clusters: 22
# KMeans ACC: 0.7550 | NMI: 0.7793 | Clusters: 20
#
# Epoch 18 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 89 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.8095 | NMI: 0.8856 | Clusters: 26
# KMeans ACC: 0.6700 | NMI: 0.7595 | Clusters: 20
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 93 clusters
# Partition 2: 25 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7735 | NMI: 0.8665 | Clusters: 25
# KMeans ACC: 0.6700 | NMI: 0.7595 | Clusters: 20
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 94 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7690 | NMI: 0.8707 | Clusters: 25
# KMeans ACC: 0.6690 | NMI: 0.7577 | Clusters: 20
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 429 clusters
# Partition 1: 93 clusters
# Partition 2: 26 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8185 | NMI: 0.8881 | Clusters: 26
# KMeans ACC: 0.6690 | NMI: 0.7577 | Clusters: 20
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 87 clusters
# Partition 2: 26 clusters
# Partition 3: 5 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.8115 | NMI: 0.8868 | Clusters: 26
# KMeans ACC: 0.6690 | NMI: 0.7577 | Clusters: 20
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 93 clusters
# Partition 2: 25 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8285 | NMI: 0.8991 | Clusters: 25
# KMeans ACC: 0.6690 | NMI: 0.7577 | Clusters: 20
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 91 clusters
# Partition 2: 25 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7770 | NMI: 0.8805 | Clusters: 25
# KMeans ACC: 0.6690 | NMI: 0.7577 | Clusters: 20
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 89 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.8395 | NMI: 0.8932 | Clusters: 26
# KMeans ACC: 0.7935 | NMI: 0.7942 | Clusters: 20
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 94 clusters
# Partition 2: 27 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.8010 | NMI: 0.8952 | Clusters: 27
# KMeans ACC: 0.7935 | NMI: 0.7943 | Clusters: 20
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 95 clusters
# Partition 2: 27 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8245 | NMI: 0.8871 | Clusters: 27
# KMeans ACC: 0.7925 | NMI: 0.7927 | Clusters: 20
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 93 clusters
# Partition 2: 23 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8705 | NMI: 0.9006 | Clusters: 23
# KMeans ACC: 0.7925 | NMI: 0.7927 | Clusters: 20
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 90 clusters
# Partition 2: 23 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.7960 | NMI: 0.8831 | Clusters: 23
# KMeans ACC: 0.7925 | NMI: 0.7927 | Clusters: 20
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 91 clusters
# Partition 2: 26 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8330 | NMI: 0.8908 | Clusters: 26
# KMeans ACC: 0.7925 | NMI: 0.7927 | Clusters: 20
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 92 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.8520 | NMI: 0.8968 | Clusters: 25
# KMeans ACC: 0.7925 | NMI: 0.7927 | Clusters: 20
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 91 clusters
# Partition 2: 24 clusters
# Partition 3: 3 clusters
# FINCH ACC: 0.8485 | NMI: 0.8979 | Clusters: 24
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 432 clusters
# Partition 1: 87 clusters
# Partition 2: 24 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8215 | NMI: 0.8833 | Clusters: 24
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 91 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7995 | NMI: 0.8788 | Clusters: 25
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 90 clusters
# Partition 2: 24 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8495 | NMI: 0.9002 | Clusters: 24
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 92 clusters
# Partition 2: 26 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7790 | NMI: 0.8727 | Clusters: 26
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 91 clusters
# Partition 2: 25 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8385 | NMI: 0.9004 | Clusters: 25
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 89 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.8385 | NMI: 0.8949 | Clusters: 25
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 93 clusters
# Partition 2: 26 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8195 | NMI: 0.8904 | Clusters: 26
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 93 clusters
# Partition 2: 25 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8125 | NMI: 0.8848 | Clusters: 25
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 89 clusters
# Partition 2: 26 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8225 | NMI: 0.8894 | Clusters: 26
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 42 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 93 clusters
# Partition 2: 22 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7520 | NMI: 0.8748 | Clusters: 22
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 43 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 93 clusters
# Partition 2: 27 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7635 | NMI: 0.8719 | Clusters: 27
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 44 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 94 clusters
# Partition 2: 29 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7485 | NMI: 0.8714 | Clusters: 29
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 45 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 89 clusters
# Partition 2: 23 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8460 | NMI: 0.8989 | Clusters: 23
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 46 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 87 clusters
# Partition 2: 24 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.8160 | NMI: 0.8821 | Clusters: 24
# KMeans ACC: 0.7930 | NMI: 0.7933 | Clusters: 20
#
# Epoch 47 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 89 clusters
# Partition 2: 25 clusters
# Partition 3: 4 clusters
# FINCH ACC: 0.8185 | NMI: 0.8915 | Clusters: 25
# KMeans ACC: 0.7600 | NMI: 0.7863 | Clusters: 20
#
# Epoch 48 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# ...
# Partition 3: 7 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7905 | NMI: 0.8790 | Clusters: 25
# KMeans ACC: 0.7080 | NMI: 0.7771 | Clusters: 20
#
# Epoch 6 | Train Loss: 0.1254
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 425 clusters
# Partition 1: 95 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7235 | NMI: 0.8618 | Clusters: 25
# KMeans ACC: 0.6635 | NMI: 0.7610 | Clusters: 20
#
# Epoch 7 | Train Loss: 0.0566
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 101 clusters
# Partition 2: 22 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7635 | NMI: 0.8682 | Clusters: 22
# KMeans ACC: 0.6940 | NMI: 0.7660 | Clusters: 20
#
# Epoch 8 | Train Loss: 0.0447
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 427 clusters
# Partition 1: 91 clusters
# Partition 2: 22 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7920 | NMI: 0.8628 | Clusters: 22
# KMeans ACC: 0.6710 | NMI: 0.7675 | Clusters: 20
#
# Epoch 9 | Train Loss: 0.0867
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 433 clusters
# Partition 1: 98 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7455 | NMI: 0.8466 | Clusters: 25
# KMeans ACC: 0.7050 | NMI: 0.7534 | Clusters: 20
#
# Epoch 10 | Train Loss: 0.0651
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 428 clusters
# Partition 1: 95 clusters
# Partition 2: 25 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7625 | NMI: 0.8591 | Clusters: 25
# KMeans ACC: 0.7770 | NMI: 0.7885 | Clusters: 20
#
# Epoch 11 | Train Loss: 0.0406
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 425 clusters
# Partition 1: 95 clusters
# Partition 2: 24 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7415 | NMI: 0.8484 | Clusters: 24
# KMeans ACC: 0.6680 | NMI: 0.7610 | Clusters: 20
#
# Epoch 12 | Train Loss: 0.0277
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 428 clusters
# Partition 1: 97 clusters
# Partition 2: 29 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7625 | NMI: 0.8693 | Clusters: 29
# KMeans ACC: 0.6875 | NMI: 0.7573 | Clusters: 20
#
# Epoch 13 | Train Loss: 0.1040
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 431 clusters
# Partition 1: 97 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7165 | NMI: 0.8602 | Clusters: 26
# KMeans ACC: 0.6145 | NMI: 0.7307 | Clusters: 20
#
# Epoch 14 | Train Loss: 0.0704
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 101 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.8105 | NMI: 0.8767 | Clusters: 25
# KMeans ACC: 0.7180 | NMI: 0.7695 | Clusters: 20
#
# Epoch 15 | Train Loss: 0.0372
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 435 clusters
# Partition 1: 95 clusters
# Partition 2: 23 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7700 | NMI: 0.8549 | Clusters: 23
# KMeans ACC: 0.6440 | NMI: 0.7490 | Clusters: 20
#
# Epoch 16 | Train Loss: 0.0482
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 100 clusters
# Partition 2: 26 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7305 | NMI: 0.8441 | Clusters: 26
# KMeans ACC: 0.7000 | NMI: 0.7591 | Clusters: 20
#
# Epoch 17 | Train Loss: 0.0030
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 98 clusters
# Partition 2: 28 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7190 | NMI: 0.8486 | Clusters: 28
# KMeans ACC: 0.7100 | NMI: 0.7648 | Clusters: 20
#
# Epoch 18 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 100 clusters
# Partition 2: 29 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7555 | NMI: 0.8588 | Clusters: 29
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 97 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7395 | NMI: 0.8583 | Clusters: 25
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 98 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7365 | NMI: 0.8472 | Clusters: 26
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 99 clusters
# Partition 2: 27 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7645 | NMI: 0.8683 | Clusters: 27
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 101 clusters
# Partition 2: 28 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7360 | NMI: 0.8489 | Clusters: 28
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 101 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7255 | NMI: 0.8577 | Clusters: 26
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 97 clusters
# Partition 2: 27 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7770 | NMI: 0.8782 | Clusters: 27
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 103 clusters
# Partition 2: 31 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6935 | NMI: 0.8485 | Clusters: 31
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 97 clusters
# Partition 2: 26 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7310 | NMI: 0.8548 | Clusters: 26
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 96 clusters
# Partition 2: 24 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7685 | NMI: 0.8908 | Clusters: 24
# KMeans ACC: 0.7115 | NMI: 0.7651 | Clusters: 20
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 98 clusters
# Partition 2: 27 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7190 | NMI: 0.8665 | Clusters: 27
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 99 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7155 | NMI: 0.8464 | Clusters: 26
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 94 clusters
# Partition 2: 27 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7050 | NMI: 0.8372 | Clusters: 27
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 104 clusters
# Partition 2: 29 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7430 | NMI: 0.8562 | Clusters: 29
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 100 clusters
# Partition 2: 25 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7200 | NMI: 0.8511 | Clusters: 25
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 102 clusters
# Partition 2: 30 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6330 | NMI: 0.8397 | Clusters: 30
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 444 clusters
# Partition 1: 99 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7255 | NMI: 0.8469 | Clusters: 26
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 442 clusters
# Partition 1: 105 clusters
# Partition 2: 26 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7490 | NMI: 0.8711 | Clusters: 26
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 99 clusters
# Partition 2: 26 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6875 | NMI: 0.8451 | Clusters: 26
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 106 clusters
# Partition 2: 31 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7385 | NMI: 0.8615 | Clusters: 31
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 437 clusters
# Partition 1: 98 clusters
# Partition 2: 28 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7410 | NMI: 0.8617 | Clusters: 28
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 96 clusters
# Partition 2: 29 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6995 | NMI: 0.8488 | Clusters: 29
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 101 clusters
# Partition 2: 25 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7210 | NMI: 0.8755 | Clusters: 25
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 440 clusters
# Partition 1: 97 clusters
# Partition 2: 28 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7560 | NMI: 0.8728 | Clusters: 28
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 42 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 436 clusters
# Partition 1: 99 clusters
# Partition 2: 27 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7565 | NMI: 0.8629 | Clusters: 27
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 43 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 102 clusters
# Partition 2: 26 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7865 | NMI: 0.8757 | Clusters: 26
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 44 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 443 clusters
# Partition 1: 96 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7060 | NMI: 0.8500 | Clusters: 25
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 45 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 439 clusters
# Partition 1: 97 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7020 | NMI: 0.8500 | Clusters: 25
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 46 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 100 clusters
# Partition 2: 26 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7495 | NMI: 0.8577 | Clusters: 26
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 47 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 434 clusters
# Partition 1: 100 clusters
# Partition 2: 27 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7495 | NMI: 0.8731 | Clusters: 27
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 48 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 99 clusters
# Partition 2: 25 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7340 | NMI: 0.8592 | Clusters: 25
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 49 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 94 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7030 | NMI: 0.8507 | Clusters: 25
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Epoch 50 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 441 clusters
# Partition 1: 96 clusters
# Partition 2: 29 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7385 | NMI: 0.8670 | Clusters: 29
# KMeans ACC: 0.6165 | NMI: 0.7499 | Clusters: 20
#
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 438 clusters
# Partition 1: 103 clusters
# Partition 2: 24 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
#
# FINCH Clustering Performance:
# Clustering Accuracy (ACC): 0.7640
# Normalized Mutual Information (NMI): 0.8696
# Number of clusters found: 24
#
# K-Means Clustering Performance: 20 Clusters
# Clustering Accuracy (ACC): 0.6165
# Normalized Mutual Information (NMI): 0.7499
# Number of clusters found: 20
#
# 📄 Hasil clustering disimpan di: clustering_metrics_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_4.csv
# 📄 Partisi FINCH disimpan di: finch_partitions_per_epoch_vit_l_16_finetuned_32labeled_20unlabeled_trial_4.csv
# Results saved to clustering_results_vit_l_16_finetuned_32labeled_20unlabeled_FINCH_KMEANS.csv
