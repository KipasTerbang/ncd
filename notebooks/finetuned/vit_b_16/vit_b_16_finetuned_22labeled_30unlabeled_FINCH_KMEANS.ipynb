# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import torchvision.transforms as transforms
from torchvision.models import vit_b_16, ViT_B_16_Weights
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
from sklearn.metrics import normalized_mutual_info_score
from sklearn.cluster import KMeans
from scipy.optimize import linear_sum_assignment
from finch import FINCH
from tqdm import tqdm

# ======================== DEVICE ========================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ======================== VIT FEATURE EXTRACTOR ========================
class ViTFeatureExtractor(nn.Module):
    def __init__(self):
        super(ViTFeatureExtractor, self).__init__()
        self.backbone = vit_b_16(weights=ViT_B_16_Weights.IMAGENET1K_V1)
        for param in self.backbone.parameters():
            param.requires_grad = False
        self.backbone.heads = nn.Identity()

    def forward(self, x):
        return self.backbone(x)

model = ViTFeatureExtractor().to(device)

# ======================== EKSTRAK FITUR & SIMPAN ========================
def extract_features_to_file(model, data_loader, save_path):
    model.eval()
    final_list = []
    with torch.no_grad():
        for images, labels in tqdm(data_loader):
            images = images.to(device)
            features = model(images).cpu().numpy()
            labels = labels.numpy()
            for feat, label in zip(features, labels):
                final_list.append([feat, label])
    np.save(save_path, np.array(final_list, dtype=object))

# ======================== CLUSTERING METRIK ========================
def clustering_accuracy(y_true, y_pred):
    D = max(y_pred.max(), y_true.max()) + 1
    w = np.zeros((D, D), dtype=np.int64)
    for i in range(y_pred.size):
        w[y_pred[i], y_true[i]] += 1
    row_ind, col_ind = linear_sum_assignment(w.max() - w)
    return w[row_ind, col_ind].sum() / y_pred.size

# ======================== FITUR EKSTRAKSI DARI CLASSIFIER ========================
def extract_features(loader, model):
    model.eval()
    all_feats, all_labels = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            feat = model.getHidden(x).cpu().numpy()
            all_feats.append(feat)
            all_labels.append(y.numpy())
    return np.concatenate(all_feats), np.concatenate(all_labels)

# ======================== DATASET FITUR ========================
class FeatureDataset(Dataset):
    def __init__(self, data):
        self.features = [item[0] for item in data]
        self.labels = [item[1] for item in data]

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return torch.tensor(self.features[idx], dtype=torch.float32), torch.tensor(self.labels[idx], dtype=torch.long)

# ======================== SIMPLE CLASSIFIER ========================
class SimpleClassifier(nn.Module):
    def __init__(self, input_dim=768, hidden_dim=3072, num_classes=12):
        super(SimpleClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        return self.model(x)

    def getHidden(self, x):
        x = self.model[0](x)
        return x

# ======================== LOOP TRIAL ========================
results_final = []

for trial in range(5):
    # Transforms
    labeled_transform = transforms.Compose([
        transforms.RandAugment(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])
    unlabeled_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])

    # Dataset
    labeled_folder = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\22labeled_30unlabeled\labeled"
    unlabeled_folder = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\22labeled_30unlabeled\unlabeled"

    labeled_dataset = ImageFolder(root=labeled_folder, transform=labeled_transform)
    unlabeled_dataset = ImageFolder(root=unlabeled_folder, transform=unlabeled_transform)

    batch_size = 16
    labeled_loader_raw = DataLoader(labeled_dataset, batch_size=batch_size, shuffle=True)
    unlabeled_loader_raw = DataLoader(unlabeled_dataset, batch_size=batch_size, shuffle=False)

    # Ekstraksi fitur
    labeled_feat_path = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\22labeled_30unlabeled\labeled_features_vit_b_16_22labeled_30unlabeled.npy"
    unlabeled_feat_path = fr"C:\Users\HP\novelty\split_datasets\trial_{trial}\22labeled_30unlabeled\unlabeled_features_vit_b_16_22labeled_30unlabeled.npy"

    # extract_features_to_file(model, labeled_loader_raw, labeled_feat_path)
    # extract_features_to_file(model, unlabeled_loader_raw, unlabeled_feat_path)

    labeled_data = np.load(labeled_feat_path, allow_pickle=True)
    unlabeled_data = np.load(unlabeled_feat_path, allow_pickle=True)

    labeled_loader = DataLoader(FeatureDataset(labeled_data), batch_size=batch_size, shuffle=True)
    unlabeled_loader = DataLoader(FeatureDataset(unlabeled_data), batch_size=batch_size, shuffle=False)

    # Classifier setup
    num_classes = len(set([l[1] for l in labeled_data]))
    classifier = SimpleClassifier(input_dim=768, hidden_dim=3072, num_classes=num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-3)

    results = []
    finch_partitions = []
    all_image_info = []

    for epoch in range(50):
        classifier.train()
        running_loss = 0.0

        for x, y in labeled_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            output = classifier(x)
            loss = criterion(output, y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(labeled_loader)
        print(f"Epoch {epoch+1} | Train Loss: {train_loss:.4f}")

        feats, true_labels = extract_features(unlabeled_loader, classifier)

        # FINCH clustering
        c, num_clust, _ = FINCH(feats, use_ann_above_samples=1000, verbose=True)
        partition_info = {"Epoch": epoch + 1}
        for i, clust in enumerate(num_clust):
            partition_info[f"Partition {i}"] = clust
        finch_partitions.append(partition_info)

        finch_clusters = c[:, 2]
        finch_nmi = normalized_mutual_info_score(true_labels, finch_clusters)
        finch_acc = clustering_accuracy(true_labels, finch_clusters)

        # KMeans clustering
        num_clusters = len(np.unique(true_labels))
        kmeans = KMeans(n_clusters=num_clusters, random_state=42).fit(feats)
        kmeans_clusters = kmeans.labels_
        kmeans_nmi = normalized_mutual_info_score(true_labels, kmeans_clusters)
        kmeans_acc = clustering_accuracy(true_labels, kmeans_clusters)

        print(f"FINCH ACC: {finch_acc:.4f} | NMI: {finch_nmi:.4f} | Clusters: {len(np.unique(finch_clusters))}")
        print(f"KMeans ACC: {kmeans_acc:.4f} | NMI: {kmeans_nmi:.4f} | Clusters: {len(np.unique(kmeans_clusters))}\n")

        results.append({
            "Epoch": epoch + 1,
            "Loss": train_loss,
            "FINCH_ACC": finch_acc,
            "FINCH_NMI": finch_nmi,
            "FINCH_Clusters": len(np.unique(finch_clusters)),
            "KMeans_ACC": kmeans_acc,
            "KMeans_NMI": kmeans_nmi,
            "KMeans_Clusters": len(np.unique(kmeans_clusters))
        })
    unlabeled_features, unlabeled_true_labels = extract_features(unlabeled_loader, classifier)
    
    c, num_clust, req_c = FINCH(unlabeled_features, use_ann_above_samples=1000, verbose=True)
    finch_clusters = c[:,2]

    finch_nmi = normalized_mutual_info_score(unlabeled_true_labels, finch_clusters)
    finch_acc = clustering_accuracy(unlabeled_true_labels, finch_clusters)

    print(f"\nFINCH Clustering Performance:")
    print(f"Clustering Accuracy (ACC): {finch_acc:.4f}")
    print(f"Normalized Mutual Information (NMI): {finch_nmi:.4f}")
    print(f"Number of clusters found: {len(np.unique(finch_clusters))}")
    
    num_clusters = len(np.unique(unlabeled_true_labels))
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans_clusters = kmeans.fit_predict(unlabeled_features)

    # ----- Evaluasi -----
    kmeans_nmi = normalized_mutual_info_score(unlabeled_true_labels, kmeans_clusters)
    kmeans_acc = clustering_accuracy(unlabeled_true_labels, kmeans_clusters)

    print(f"\nK-Means Clustering Performance: {num_clusters} Clusters")
    print(f"Clustering Accuracy (ACC): {kmeans_acc:.4f}")
    print(f"Normalized Mutual Information (NMI): {kmeans_nmi:.4f}")
    print(f"Number of clusters found: {len(np.unique(kmeans_clusters))}")
    
    # Simpan hasil trial ini
    results_final.append({
        'trial': trial,
        'FINCH_ACC': finch_acc,
        'FINCH_NMI': finch_nmi,
        'FINCH_Num_Clusters': len(np.unique(finch_clusters)),
        'KMeans_ACC': kmeans_acc,
        'KMeans_NMI': kmeans_nmi,
        'KMeans_Num_Clusters': len(np.unique(kmeans_clusters)),
    })
    
    # Simpan hasil per gambar
    for i in range(len(unlabeled_dataset)):
        path, true_label = unlabeled_dataset.samples[i]
        image_info = {
            'trial': trial,
            'image_path': path,
            'true_label': true_label,
            'finch_cluster': int(finch_clusters[i]),
            'kmeans_cluster': int(kmeans_clusters[i])
        }
        all_image_info.append(image_info)

    # Simpan file CSV per trial
    df_trial_detail = pd.DataFrame(all_image_info[-len(unlabeled_dataset):])  # ambil data dari trial ini saja
    df_trial_detail.to_csv(f'vit_b_16_finetuned_22labeled_30unlabeled_trial_{trial}_image_clustering.csv', index=False)

    # Simpan hasil
    result_csv = fr"clustering_metrics_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_{trial}.csv"
    partition_csv = fr"finch_partitions_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_{trial}.csv"

    pd.DataFrame(results).to_csv(result_csv, index=False)
    pd.DataFrame(finch_partitions).to_csv(partition_csv, index=False)

    print(f"\n📄 Hasil clustering disimpan di: {result_csv}")
    print(f"📄 Partisi FINCH disimpan di: {partition_csv}")

df_results = pd.DataFrame(results_final)
mean_values = df_results.select_dtypes(include=np.number).mean()

mean_row = pd.DataFrame({
    'trial': ['Average'],
    'FINCH_ACC': [mean_values['FINCH_ACC']],
    'FINCH_NMI': [mean_values['FINCH_NMI']],
    'FINCH_Num_Clusters': [mean_values['FINCH_Num_Clusters']],
    'KMeans_ACC': [mean_values['KMeans_ACC']],
    'KMeans_NMI': [mean_values['KMeans_NMI']],
    'KMeans_Num_Clusters': [mean_values['KMeans_Num_Clusters']]
})

df_results = pd.concat([df_results, mean_row], ignore_index=True)

df_results.to_csv('clustering_results_vit_b_16_finetuned_22labeled_30unlabeled_FINCH_KMEANS.csv', index=False)
print("Results saved to clustering_results_vit_b_16_finetuned_22labeled_30unlabeled_FINCH_KMEANS.csv")
# Out:
# Epoch 1 | Train Loss: 0.4790
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 604 clusters
# Partition 1: 121 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7210 | NMI: 0.8373 | Clusters: 34
# KMeans ACC: 0.6950 | NMI: 0.7740 | Clusters: 30
#
# Epoch 2 | Train Loss: 0.1164
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 598 clusters
# Partition 1: 125 clusters
# Partition 2: 34 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7060 | NMI: 0.8226 | Clusters: 34
# KMeans ACC: 0.6947 | NMI: 0.7501 | Clusters: 30
#
# Epoch 3 | Train Loss: 0.0444
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 625 clusters
# Partition 1: 135 clusters
# Partition 2: 36 clusters
# Partition 3: 12 clusters
# Partition 4: 4 clusters
# FINCH ACC: 0.6717 | NMI: 0.8037 | Clusters: 36
# KMeans ACC: 0.7113 | NMI: 0.7648 | Clusters: 30
#
# Epoch 4 | Train Loss: 0.0612
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 632 clusters
# Partition 1: 140 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7097 | NMI: 0.8159 | Clusters: 32
# KMeans ACC: 0.6877 | NMI: 0.7589 | Clusters: 30
#
# Epoch 5 | Train Loss: 0.0183
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 625 clusters
# Partition 1: 121 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7337 | NMI: 0.8269 | Clusters: 34
# KMeans ACC: 0.7093 | NMI: 0.7654 | Clusters: 30
#
# Epoch 6 | Train Loss: 0.0178
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 635 clusters
# Partition 1: 128 clusters
# Partition 2: 36 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7057 | NMI: 0.8007 | Clusters: 36
# KMeans ACC: 0.7253 | NMI: 0.7649 | Clusters: 30
#
# Epoch 7 | Train Loss: 0.1166
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 627 clusters
# Partition 1: 131 clusters
# Partition 2: 32 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7170 | NMI: 0.8160 | Clusters: 32
# KMeans ACC: 0.6637 | NMI: 0.7273 | Clusters: 30
#
# Epoch 8 | Train Loss: 0.1470
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 634 clusters
# Partition 1: 140 clusters
# Partition 2: 34 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6917 | NMI: 0.8009 | Clusters: 34
# KMeans ACC: 0.6653 | NMI: 0.7280 | Clusters: 30
#
# Epoch 9 | Train Loss: 0.0804
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 632 clusters
# Partition 1: 130 clusters
# Partition 2: 30 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.6990 | NMI: 0.7961 | Clusters: 30
# KMeans ACC: 0.6960 | NMI: 0.7384 | Clusters: 30
#
# Epoch 10 | Train Loss: 0.0535
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 618 clusters
# Partition 1: 135 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7473 | NMI: 0.8257 | Clusters: 32
# KMeans ACC: 0.6670 | NMI: 0.7296 | Clusters: 30
#
# Epoch 11 | Train Loss: 0.0200
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 628 clusters
# Partition 1: 134 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7230 | NMI: 0.8097 | Clusters: 30
# KMeans ACC: 0.7070 | NMI: 0.7423 | Clusters: 30
#
# Epoch 12 | Train Loss: 0.0323
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 628 clusters
# Partition 1: 135 clusters
# Partition 2: 31 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6737 | NMI: 0.7863 | Clusters: 31
# KMeans ACC: 0.7083 | NMI: 0.7447 | Clusters: 30
#
# Epoch 13 | Train Loss: 0.0208
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 127 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7557 | NMI: 0.8155 | Clusters: 30
# KMeans ACC: 0.6527 | NMI: 0.7400 | Clusters: 30
#
# Epoch 14 | Train Loss: 0.0002
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 612 clusters
# Partition 1: 130 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7407 | NMI: 0.8262 | Clusters: 32
# KMeans ACC: 0.6523 | NMI: 0.7297 | Clusters: 30
#
# Epoch 15 | Train Loss: 0.0027
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 134 clusters
# Partition 2: 30 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7207 | NMI: 0.8136 | Clusters: 30
# KMeans ACC: 0.7013 | NMI: 0.7438 | Clusters: 30
#
# Epoch 16 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 128 clusters
# Partition 2: 30 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7253 | NMI: 0.8064 | Clusters: 30
# KMeans ACC: 0.6367 | NMI: 0.7291 | Clusters: 30
#
# Epoch 17 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 618 clusters
# Partition 1: 128 clusters
# Partition 2: 29 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7170 | NMI: 0.8134 | Clusters: 29
# KMeans ACC: 0.6893 | NMI: 0.7484 | Clusters: 30
#
# Epoch 18 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 623 clusters
# Partition 1: 132 clusters
# Partition 2: 36 clusters
# Partition 3: 11 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7030 | NMI: 0.8203 | Clusters: 36
# KMeans ACC: 0.7103 | NMI: 0.7586 | Clusters: 30
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 137 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7327 | NMI: 0.8195 | Clusters: 32
# KMeans ACC: 0.7090 | NMI: 0.7578 | Clusters: 30
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 621 clusters
# Partition 1: 128 clusters
# Partition 2: 30 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7050 | NMI: 0.8084 | Clusters: 30
# KMeans ACC: 0.7090 | NMI: 0.7578 | Clusters: 30
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 126 clusters
# Partition 2: 31 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7513 | NMI: 0.8298 | Clusters: 31
# KMeans ACC: 0.7070 | NMI: 0.7570 | Clusters: 30
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 129 clusters
# Partition 2: 34 clusters
# Partition 3: 12 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7093 | NMI: 0.8141 | Clusters: 34
# KMeans ACC: 0.7073 | NMI: 0.7582 | Clusters: 30
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 613 clusters
# Partition 1: 124 clusters
# Partition 2: 30 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7280 | NMI: 0.8048 | Clusters: 30
# KMeans ACC: 0.7073 | NMI: 0.7555 | Clusters: 30
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 618 clusters
# Partition 1: 134 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7123 | NMI: 0.8116 | Clusters: 30
# KMeans ACC: 0.7097 | NMI: 0.7578 | Clusters: 30
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 621 clusters
# Partition 1: 135 clusters
# Partition 2: 29 clusters
# Partition 3: 11 clusters
# FINCH ACC: 0.7083 | NMI: 0.8134 | Clusters: 29
# KMeans ACC: 0.7080 | NMI: 0.7573 | Clusters: 30
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 623 clusters
# Partition 1: 134 clusters
# Partition 2: 34 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.7427 | NMI: 0.8173 | Clusters: 34
# KMeans ACC: 0.7097 | NMI: 0.7576 | Clusters: 30
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 621 clusters
# Partition 1: 133 clusters
# Partition 2: 33 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7387 | NMI: 0.8235 | Clusters: 33
# KMeans ACC: 0.7033 | NMI: 0.7448 | Clusters: 30
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 622 clusters
# Partition 1: 127 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7233 | NMI: 0.8098 | Clusters: 34
# KMeans ACC: 0.7033 | NMI: 0.7446 | Clusters: 30
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 625 clusters
# Partition 1: 131 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7563 | NMI: 0.8168 | Clusters: 32
# KMeans ACC: 0.7210 | NMI: 0.7560 | Clusters: 30
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 616 clusters
# Partition 1: 137 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7507 | NMI: 0.8280 | Clusters: 32
# KMeans ACC: 0.7217 | NMI: 0.7565 | Clusters: 30
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 622 clusters
# Partition 1: 136 clusters
# Partition 2: 35 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7140 | NMI: 0.8144 | Clusters: 35
# KMeans ACC: 0.7033 | NMI: 0.7437 | Clusters: 30
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 621 clusters
# Partition 1: 136 clusters
# Partition 2: 33 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7057 | NMI: 0.8084 | Clusters: 33
# KMeans ACC: 0.7033 | NMI: 0.7437 | Clusters: 30
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 130 clusters
# Partition 2: 31 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6837 | NMI: 0.8088 | Clusters: 31
# KMeans ACC: 0.7033 | NMI: 0.7437 | Clusters: 30
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 130 clusters
# Partition 2: 29 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.7377 | NMI: 0.8221 | Clusters: 29
# KMeans ACC: 0.7033 | NMI: 0.7437 | Clusters: 30
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 128 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6717 | NMI: 0.8130 | Clusters: 30
# KMeans ACC: 0.7033 | NMI: 0.7437 | Clusters: 30
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 137 clusters
# Partition 2: 32 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6767 | NMI: 0.8049 | Clusters: 32
# KMeans ACC: 0.7203 | NMI: 0.7544 | Clusters: 30
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 134 clusters
# Partition 2: 29 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7100 | NMI: 0.8145 | Clusters: 29
# KMeans ACC: 0.7203 | NMI: 0.7544 | Clusters: 30
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 133 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6997 | NMI: 0.8093 | Clusters: 32
# KMeans ACC: 0.7033 | NMI: 0.7443 | Clusters: 30
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 141 clusters
# Partition 2: 34 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7423 | NMI: 0.8156 | Clusters: 34
# KMeans ACC: 0.7193 | NMI: 0.7534 | Clusters: 30
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 616 clusters
# Partition 1: 131 clusters
# Partition 2: 33 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7250 | NMI: 0.8135 | Clusters: 33
# KMeans ACC: 0.7187 | NMI: 0.7536 | Clusters: 30
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 618 clusters
# Partition 1: 131 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7420 | NMI: 0.8128 | Clusters: 32
# KMeans ACC: 0.6937 | NMI: 0.7490 | Clusters: 30
#
# Epoch 42 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 131 clusters
# Partition 2: 30 clusters
# Partition 3: 6 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7657 | NMI: 0.8140 | Clusters: 30
# KMeans ACC: 0.7127 | NMI: 0.7518 | Clusters: 30
#
# Epoch 43 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 121 clusters
# Partition 2: 29 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7367 | NMI: 0.8096 | Clusters: 29
# KMeans ACC: 0.7130 | NMI: 0.7517 | Clusters: 30
#
# Epoch 44 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 129 clusters
# Partition 2: 33 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7310 | NMI: 0.8182 | Clusters: 33
# KMeans ACC: 0.7130 | NMI: 0.7564 | Clusters: 30
#
# Epoch 45 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 127 clusters
# Partition 2: 31 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7073 | NMI: 0.8091 | Clusters: 31
# KMeans ACC: 0.7130 | NMI: 0.7564 | Clusters: 30
#
# Epoch 46 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 124 clusters
# Partition 2: 25 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7040 | NMI: 0.8064 | Clusters: 25
# KMeans ACC: 0.7130 | NMI: 0.7564 | Clusters: 30
#
# Epoch 47 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 623 clusters
# Partition 1: 137 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7443 | NMI: 0.8274 | Clusters: 34
# KMeans ACC: 0.6807 | NMI: 0.7600 | Clusters: 30
#
# Epoch 48 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 623 clusters
# Partition 1: 134 clusters
# Partition 2: 33 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7063 | NMI: 0.7983 | Clusters: 33
# KMeans ACC: 0.6810 | NMI: 0.7600 | Clusters: 30
#
# Epoch 49 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 122 clusters
# Partition 2: 33 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7447 | NMI: 0.8075 | Clusters: 33
# KMeans ACC: 0.6810 | NMI: 0.7600 | Clusters: 30
#
# Epoch 50 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 616 clusters
# Partition 1: 135 clusters
# Partition 2: 34 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7173 | NMI: 0.8073 | Clusters: 34
# KMeans ACC: 0.6810 | NMI: 0.7600 | Clusters: 30
#
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 126 clusters
# Partition 2: 30 clusters
# Partition 3: 5 clusters
# Partition 4: 2 clusters
#
# FINCH Clustering Performance:
# Clustering Accuracy (ACC): 0.7373
# Normalized Mutual Information (NMI): 0.8034
# Number of clusters found: 30
#
# K-Means Clustering Performance: 30 Clusters
# Clustering Accuracy (ACC): 0.6810
# Normalized Mutual Information (NMI): 0.7600
# Number of clusters found: 30
#
# 📄 Hasil clustering disimpan di: clustering_metrics_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_0.csv
# 📄 Partisi FINCH disimpan di: finch_partitions_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_0.csv
# Epoch 1 | Train Loss: 0.4720
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 579 clusters
# Partition 1: 121 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6097 | NMI: 0.7899 | Clusters: 30
# KMeans ACC: 0.6610 | NMI: 0.7459 | Clusters: 30
#
# Epoch 2 | Train Loss: 0.0732
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 599 clusters
# Partition 1: 130 clusters
# Partition 2: 37 clusters
# Partition 3: 13 clusters
# Partition 4: 5 clusters
# Partition 5: 2 clusters
# FINCH ACC: 0.6870 | NMI: 0.7987 | Clusters: 37
# KMeans ACC: 0.7237 | NMI: 0.7700 | Clusters: 30
#
# Epoch 3 | Train Loss: 0.0659
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 603 clusters
# Partition 1: 133 clusters
# Partition 2: 35 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7057 | NMI: 0.8008 | Clusters: 35
# KMeans ACC: 0.6997 | NMI: 0.7563 | Clusters: 30
#
# Epoch 4 | Train Loss: 0.0359
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 595 clusters
# Partition 1: 128 clusters
# Partition 2: 38 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6703 | NMI: 0.7953 | Clusters: 38
# KMeans ACC: 0.6570 | NMI: 0.7280 | Clusters: 30
#
# Epoch 5 | Train Loss: 0.0060
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 618 clusters
# Partition 1: 133 clusters
# Partition 2: 39 clusters
# Partition 3: 12 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7053 | NMI: 0.8130 | Clusters: 39
# KMeans ACC: 0.7427 | NMI: 0.7748 | Clusters: 30
#
# Epoch 6 | Train Loss: 0.0113
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 131 clusters
# Partition 2: 40 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6703 | NMI: 0.8008 | Clusters: 40
# KMeans ACC: 0.7197 | NMI: 0.7651 | Clusters: 30
#
# Epoch 7 | Train Loss: 0.0894
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 582 clusters
# Partition 1: 115 clusters
# Partition 2: 27 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6603 | NMI: 0.7683 | Clusters: 27
# KMeans ACC: 0.7320 | NMI: 0.7596 | Clusters: 30
#
# Epoch 8 | Train Loss: 0.1490
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 575 clusters
# Partition 1: 114 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6990 | NMI: 0.8049 | Clusters: 34
# KMeans ACC: 0.6930 | NMI: 0.7369 | Clusters: 30
#
# Epoch 9 | Train Loss: 0.0785
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 579 clusters
# Partition 1: 119 clusters
# Partition 2: 34 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.6690 | NMI: 0.7973 | Clusters: 34
# KMeans ACC: 0.6557 | NMI: 0.7254 | Clusters: 30
#
# Epoch 10 | Train Loss: 0.0546
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 576 clusters
# Partition 1: 122 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.6930 | NMI: 0.7882 | Clusters: 32
# KMeans ACC: 0.6110 | NMI: 0.6968 | Clusters: 30
#
# Epoch 11 | Train Loss: 0.0546
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 573 clusters
# Partition 1: 127 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6183 | NMI: 0.7721 | Clusters: 32
# KMeans ACC: 0.6520 | NMI: 0.7159 | Clusters: 30
#
# Epoch 12 | Train Loss: 0.0230
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 570 clusters
# Partition 1: 125 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6393 | NMI: 0.7646 | Clusters: 32
# KMeans ACC: 0.6513 | NMI: 0.7166 | Clusters: 30
#
# Epoch 13 | Train Loss: 0.0054
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 568 clusters
# Partition 1: 118 clusters
# Partition 2: 31 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6467 | NMI: 0.7750 | Clusters: 31
# KMeans ACC: 0.6690 | NMI: 0.7114 | Clusters: 30
#
# Epoch 14 | Train Loss: 0.0034
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 586 clusters
# Partition 1: 127 clusters
# Partition 2: 34 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6580 | NMI: 0.7771 | Clusters: 34
# KMeans ACC: 0.6617 | NMI: 0.7147 | Clusters: 30
#
# Epoch 15 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 581 clusters
# Partition 1: 132 clusters
# Partition 2: 34 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6877 | NMI: 0.7934 | Clusters: 34
# KMeans ACC: 0.6440 | NMI: 0.7042 | Clusters: 30
#
# Epoch 16 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 580 clusters
# Partition 1: 121 clusters
# Partition 2: 32 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6810 | NMI: 0.7842 | Clusters: 32
# KMeans ACC: 0.6433 | NMI: 0.7046 | Clusters: 30
#
# Epoch 17 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 581 clusters
# Partition 1: 122 clusters
# Partition 2: 33 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6903 | NMI: 0.7996 | Clusters: 33
# KMeans ACC: 0.6440 | NMI: 0.7049 | Clusters: 30
#
# Epoch 18 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 580 clusters
# Partition 1: 128 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7010 | NMI: 0.8038 | Clusters: 32
# KMeans ACC: 0.6447 | NMI: 0.7048 | Clusters: 30
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 579 clusters
# Partition 1: 129 clusters
# Partition 2: 34 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7093 | NMI: 0.7991 | Clusters: 34
# KMeans ACC: 0.6460 | NMI: 0.7082 | Clusters: 30
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 581 clusters
# Partition 1: 116 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6530 | NMI: 0.7850 | Clusters: 30
# KMeans ACC: 0.6460 | NMI: 0.7082 | Clusters: 30
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 585 clusters
# Partition 1: 115 clusters
# Partition 2: 30 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7123 | NMI: 0.7998 | Clusters: 30
# KMeans ACC: 0.6450 | NMI: 0.7068 | Clusters: 30
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 576 clusters
# Partition 1: 125 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6597 | NMI: 0.7904 | Clusters: 35
# KMeans ACC: 0.6453 | NMI: 0.7077 | Clusters: 30
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 579 clusters
# Partition 1: 122 clusters
# Partition 2: 33 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6623 | NMI: 0.7911 | Clusters: 33
# KMeans ACC: 0.6813 | NMI: 0.7259 | Clusters: 30
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 578 clusters
# Partition 1: 123 clusters
# Partition 2: 30 clusters
# Partition 3: 5 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6587 | NMI: 0.7798 | Clusters: 30
# KMeans ACC: 0.6620 | NMI: 0.7192 | Clusters: 30
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 581 clusters
# Partition 1: 121 clusters
# Partition 2: 32 clusters
# Partition 3: 10 clusters
# FINCH ACC: 0.6207 | NMI: 0.7709 | Clusters: 32
# KMeans ACC: 0.6707 | NMI: 0.7292 | Clusters: 30
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 572 clusters
# Partition 1: 119 clusters
# Partition 2: 30 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6540 | NMI: 0.7867 | Clusters: 30
# KMeans ACC: 0.6697 | NMI: 0.7278 | Clusters: 30
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 577 clusters
# Partition 1: 128 clusters
# Partition 2: 33 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6897 | NMI: 0.7876 | Clusters: 33
# KMeans ACC: 0.6707 | NMI: 0.7268 | Clusters: 30
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 583 clusters
# Partition 1: 121 clusters
# Partition 2: 29 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6537 | NMI: 0.7770 | Clusters: 29
# KMeans ACC: 0.6707 | NMI: 0.7268 | Clusters: 30
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 583 clusters
# Partition 1: 119 clusters
# Partition 2: 31 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6737 | NMI: 0.7867 | Clusters: 31
# KMeans ACC: 0.6257 | NMI: 0.6981 | Clusters: 30
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 580 clusters
# Partition 1: 129 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6560 | NMI: 0.7733 | Clusters: 32
# KMeans ACC: 0.6250 | NMI: 0.6977 | Clusters: 30
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 581 clusters
# Partition 1: 130 clusters
# Partition 2: 33 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6893 | NMI: 0.7982 | Clusters: 33
# KMeans ACC: 0.6247 | NMI: 0.6981 | Clusters: 30
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 583 clusters
# Partition 1: 123 clusters
# Partition 2: 33 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6917 | NMI: 0.7940 | Clusters: 33
# KMeans ACC: 0.6243 | NMI: 0.6981 | Clusters: 30
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 583 clusters
# Partition 1: 130 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6737 | NMI: 0.7970 | Clusters: 32
# KMeans ACC: 0.6273 | NMI: 0.6987 | Clusters: 30
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 583 clusters
# Partition 1: 115 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7097 | NMI: 0.7913 | Clusters: 30
# KMeans ACC: 0.6247 | NMI: 0.6978 | Clusters: 30
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 580 clusters
# Partition 1: 132 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6397 | NMI: 0.7763 | Clusters: 34
# KMeans ACC: 0.6247 | NMI: 0.6977 | Clusters: 30
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 583 clusters
# Partition 1: 123 clusters
# Partition 2: 33 clusters
# Partition 3: 11 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6640 | NMI: 0.7862 | Clusters: 33
# KMeans ACC: 0.6247 | NMI: 0.6977 | Clusters: 30
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 584 clusters
# Partition 1: 124 clusters
# Partition 2: 34 clusters
# Partition 3: 11 clusters
# Partition 4: 4 clusters
# FINCH ACC: 0.6463 | NMI: 0.7905 | Clusters: 34
# KMeans ACC: 0.6247 | NMI: 0.6977 | Clusters: 30
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 581 clusters
# Partition 1: 119 clusters
# Partition 2: 31 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6820 | NMI: 0.7856 | Clusters: 31
# KMeans ACC: 0.6247 | NMI: 0.6977 | Clusters: 30
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 582 clusters
# Partition 1: 134 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6363 | NMI: 0.7794 | Clusters: 35
# KMeans ACC: 0.6247 | NMI: 0.6979 | Clusters: 30
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 584 clusters
# Partition 1: 124 clusters
# Partition 2: 30 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.6120 | NMI: 0.7674 | Clusters: 30
# KMeans ACC: 0.6247 | NMI: 0.6978 | Clusters: 30
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 576 clusters
# Partition 1: 122 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6983 | NMI: 0.7872 | Clusters: 32
# KMeans ACC: 0.6253 | NMI: 0.6980 | Clusters: 30
#
# Epoch 42 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 581 clusters
# Partition 1: 121 clusters
# Partition 2: 35 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6777 | NMI: 0.7817 | Clusters: 35
# KMeans ACC: 0.6280 | NMI: 0.6989 | Clusters: 30
#
# Epoch 43 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 584 clusters
# Partition 1: 124 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6947 | NMI: 0.7938 | Clusters: 32
# KMeans ACC: 0.6253 | NMI: 0.6980 | Clusters: 30
#
# Epoch 44 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 579 clusters
# Partition 1: 126 clusters
# Partition 2: 33 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6657 | NMI: 0.7809 | Clusters: 33
# KMeans ACC: 0.6797 | NMI: 0.7191 | Clusters: 30
#
# Epoch 45 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 582 clusters
# Partition 1: 129 clusters
# Partition 2: 36 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6897 | NMI: 0.7937 | Clusters: 36
# KMeans ACC: 0.6793 | NMI: 0.7195 | Clusters: 30
#
# Epoch 46 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 582 clusters
# Partition 1: 128 clusters
# Partition 2: 33 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.6737 | NMI: 0.7947 | Clusters: 33
# KMeans ACC: 0.6797 | NMI: 0.7196 | Clusters: 30
#
# Epoch 47 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 574 clusters
# Partition 1: 124 clusters
# Partition 2: 33 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6737 | NMI: 0.7947 | Clusters: 33
# KMeans ACC: 0.6803 | NMI: 0.7199 | Clusters: 30
#
# Epoch 48 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 584 clusters
# Partition 1: 125 clusters
# Partition 2: 32 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6773 | NMI: 0.8026 | Clusters: 32
# KMeans ACC: 0.6467 | NMI: 0.7243 | Clusters: 30
#
# Epoch 49 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 582 clusters
# Partition 1: 121 clusters
# Partition 2: 30 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6573 | NMI: 0.7928 | Clusters: 30
# KMeans ACC: 0.6467 | NMI: 0.7242 | Clusters: 30
#
# Epoch 50 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 578 clusters
# Partition 1: 118 clusters
# Partition 2: 27 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.5920 | NMI: 0.7593 | Clusters: 27
# KMeans ACC: 0.6497 | NMI: 0.7257 | Clusters: 30
#
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 586 clusters
# Partition 1: 123 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
#
# FINCH Clustering Performance:
# Clustering Accuracy (ACC): 0.6603
# Normalized Mutual Information (NMI): 0.7769
# Number of clusters found: 35
#
# K-Means Clustering Performance: 30 Clusters
# Clustering Accuracy (ACC): 0.6497
# Normalized Mutual Information (NMI): 0.7257
# Number of clusters found: 30
#
# 📄 Hasil clustering disimpan di: clustering_metrics_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_1.csv
# 📄 Partisi FINCH disimpan di: finch_partitions_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_1.csv
# Epoch 1 | Train Loss: 0.4874
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 598 clusters
# Partition 1: 118 clusters
# Partition 2: 33 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6873 | NMI: 0.8018 | Clusters: 33
# KMeans ACC: 0.6803 | NMI: 0.7489 | Clusters: 30
#
# Epoch 2 | Train Loss: 0.0846
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 598 clusters
# Partition 1: 123 clusters
# Partition 2: 34 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6770 | NMI: 0.7911 | Clusters: 34
# KMeans ACC: 0.6693 | NMI: 0.7360 | Clusters: 30
#
# Epoch 3 | Train Loss: 0.0416
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 120 clusters
# Partition 2: 34 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7320 | NMI: 0.7946 | Clusters: 34
# KMeans ACC: 0.6507 | NMI: 0.7424 | Clusters: 30
#
# Epoch 4 | Train Loss: 0.0374
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 617 clusters
# Partition 1: 123 clusters
# Partition 2: 37 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6910 | NMI: 0.7947 | Clusters: 37
# KMeans ACC: 0.7023 | NMI: 0.7439 | Clusters: 30
#
# Epoch 5 | Train Loss: 0.0917
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 601 clusters
# Partition 1: 130 clusters
# Partition 2: 31 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6807 | NMI: 0.7728 | Clusters: 31
# KMeans ACC: 0.7080 | NMI: 0.7450 | Clusters: 30
#
# Epoch 6 | Train Loss: 0.0972
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 623 clusters
# Partition 1: 129 clusters
# Partition 2: 31 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6680 | NMI: 0.7813 | Clusters: 31
# KMeans ACC: 0.6983 | NMI: 0.7350 | Clusters: 30
#
# Epoch 7 | Train Loss: 0.0358
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 620 clusters
# Partition 1: 138 clusters
# Partition 2: 39 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.7060 | NMI: 0.8017 | Clusters: 39
# KMeans ACC: 0.6997 | NMI: 0.7423 | Clusters: 30
#
# Epoch 8 | Train Loss: 0.0513
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 618 clusters
# Partition 1: 129 clusters
# Partition 2: 34 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6547 | NMI: 0.7819 | Clusters: 34
# KMeans ACC: 0.6813 | NMI: 0.7302 | Clusters: 30
#
# Epoch 9 | Train Loss: 0.0147
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 618 clusters
# Partition 1: 134 clusters
# Partition 2: 34 clusters
# Partition 3: 10 clusters
# Partition 4: 4 clusters
# FINCH ACC: 0.6327 | NMI: 0.7660 | Clusters: 34
# KMeans ACC: 0.6543 | NMI: 0.7260 | Clusters: 30
#
# Epoch 10 | Train Loss: 0.0369
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 137 clusters
# Partition 2: 37 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6587 | NMI: 0.7795 | Clusters: 37
# KMeans ACC: 0.6853 | NMI: 0.7260 | Clusters: 30
#
# Epoch 11 | Train Loss: 0.0418
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 616 clusters
# Partition 1: 123 clusters
# Partition 2: 31 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7270 | NMI: 0.7835 | Clusters: 31
# KMeans ACC: 0.7100 | NMI: 0.7357 | Clusters: 30
#
# Epoch 12 | Train Loss: 0.0220
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 633 clusters
# Partition 1: 134 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6683 | NMI: 0.7802 | Clusters: 35
# KMeans ACC: 0.6793 | NMI: 0.7357 | Clusters: 30
#
# Epoch 13 | Train Loss: 0.0129
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 621 clusters
# Partition 1: 135 clusters
# Partition 2: 37 clusters
# Partition 3: 12 clusters
# Partition 4: 4 clusters
# FINCH ACC: 0.6667 | NMI: 0.7867 | Clusters: 37
# KMeans ACC: 0.7003 | NMI: 0.7397 | Clusters: 30
#
# Epoch 14 | Train Loss: 0.0039
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 135 clusters
# Partition 2: 35 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.7077 | NMI: 0.7833 | Clusters: 35
# KMeans ACC: 0.6960 | NMI: 0.7307 | Clusters: 30
#
# Epoch 15 | Train Loss: 0.0002
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 609 clusters
# Partition 1: 130 clusters
# Partition 2: 35 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6987 | NMI: 0.7823 | Clusters: 35
# KMeans ACC: 0.6890 | NMI: 0.7238 | Clusters: 30
#
# Epoch 16 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 132 clusters
# Partition 2: 33 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7160 | NMI: 0.7858 | Clusters: 33
# KMeans ACC: 0.6403 | NMI: 0.7159 | Clusters: 30
#
# Epoch 17 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 132 clusters
# Partition 2: 38 clusters
# Partition 3: 11 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7053 | NMI: 0.7850 | Clusters: 38
# KMeans ACC: 0.6680 | NMI: 0.7248 | Clusters: 30
#
# Epoch 18 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 127 clusters
# Partition 2: 34 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.6677 | NMI: 0.7721 | Clusters: 34
# KMeans ACC: 0.6633 | NMI: 0.7305 | Clusters: 30
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 612 clusters
# Partition 1: 132 clusters
# Partition 2: 37 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.7063 | NMI: 0.8005 | Clusters: 37
# KMeans ACC: 0.6640 | NMI: 0.7312 | Clusters: 30
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 606 clusters
# Partition 1: 131 clusters
# Partition 2: 34 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.6850 | NMI: 0.7823 | Clusters: 34
# KMeans ACC: 0.6593 | NMI: 0.7247 | Clusters: 30
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 127 clusters
# Partition 2: 35 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.7117 | NMI: 0.7840 | Clusters: 35
# KMeans ACC: 0.6590 | NMI: 0.7237 | Clusters: 30
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 612 clusters
# Partition 1: 136 clusters
# Partition 2: 34 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.6770 | NMI: 0.7722 | Clusters: 34
# KMeans ACC: 0.6607 | NMI: 0.7240 | Clusters: 30
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 132 clusters
# Partition 2: 32 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7023 | NMI: 0.7857 | Clusters: 32
# KMeans ACC: 0.6587 | NMI: 0.7228 | Clusters: 30
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 615 clusters
# Partition 1: 131 clusters
# Partition 2: 37 clusters
# Partition 3: 10 clusters
# FINCH ACC: 0.6650 | NMI: 0.7787 | Clusters: 37
# KMeans ACC: 0.6610 | NMI: 0.7258 | Clusters: 30
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 613 clusters
# Partition 1: 131 clusters
# Partition 2: 37 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6647 | NMI: 0.7649 | Clusters: 37
# KMeans ACC: 0.6960 | NMI: 0.7372 | Clusters: 30
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 129 clusters
# Partition 2: 35 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.7277 | NMI: 0.7934 | Clusters: 35
# KMeans ACC: 0.6963 | NMI: 0.7374 | Clusters: 30
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 131 clusters
# Partition 2: 34 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6543 | NMI: 0.7671 | Clusters: 34
# KMeans ACC: 0.7020 | NMI: 0.7353 | Clusters: 30
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 137 clusters
# Partition 2: 39 clusters
# Partition 3: 13 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6637 | NMI: 0.7896 | Clusters: 39
# KMeans ACC: 0.7023 | NMI: 0.7356 | Clusters: 30
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 609 clusters
# Partition 1: 131 clusters
# Partition 2: 33 clusters
# Partition 3: 5 clusters
# FINCH ACC: 0.6897 | NMI: 0.7840 | Clusters: 33
# KMeans ACC: 0.7023 | NMI: 0.7356 | Clusters: 30
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 136 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.6883 | NMI: 0.7829 | Clusters: 35
# KMeans ACC: 0.7080 | NMI: 0.7282 | Clusters: 30
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 136 clusters
# Partition 2: 41 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7007 | NMI: 0.7919 | Clusters: 41
# KMeans ACC: 0.7133 | NMI: 0.7300 | Clusters: 30
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 606 clusters
# Partition 1: 126 clusters
# Partition 2: 33 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6573 | NMI: 0.7801 | Clusters: 33
# KMeans ACC: 0.7100 | NMI: 0.7287 | Clusters: 30
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 604 clusters
# Partition 1: 130 clusters
# Partition 2: 36 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6723 | NMI: 0.7810 | Clusters: 36
# KMeans ACC: 0.7117 | NMI: 0.7297 | Clusters: 30
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 612 clusters
# Partition 1: 131 clusters
# Partition 2: 35 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7067 | NMI: 0.7882 | Clusters: 35
# KMeans ACC: 0.7117 | NMI: 0.7313 | Clusters: 30
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 597 clusters
# Partition 1: 135 clusters
# Partition 2: 38 clusters
# Partition 3: 10 clusters
# FINCH ACC: 0.6747 | NMI: 0.7761 | Clusters: 38
# KMeans ACC: 0.6880 | NMI: 0.7338 | Clusters: 30
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 131 clusters
# Partition 2: 32 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6967 | NMI: 0.7867 | Clusters: 32
# KMeans ACC: 0.7007 | NMI: 0.7362 | Clusters: 30
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 616 clusters
# Partition 1: 135 clusters
# Partition 2: 31 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.6567 | NMI: 0.7706 | Clusters: 31
# KMeans ACC: 0.6810 | NMI: 0.7267 | Clusters: 30
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 604 clusters
# Partition 1: 137 clusters
# Partition 2: 36 clusters
# Partition 3: 8 clusters
# FINCH ACC: 0.7123 | NMI: 0.7929 | Clusters: 36
# KMeans ACC: 0.6803 | NMI: 0.7253 | Clusters: 30
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 605 clusters
# Partition 1: 121 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6873 | NMI: 0.7827 | Clusters: 34
# KMeans ACC: 0.6820 | NMI: 0.7248 | Clusters: 30
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 129 clusters
# Partition 2: 34 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6743 | NMI: 0.7847 | Clusters: 34
# KMeans ACC: 0.6203 | NMI: 0.7158 | Clusters: 30
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 605 clusters
# Partition 1: 134 clusters
# Partition 2: 34 clusters
# Partition 3: 7 clusters
# ...
# KMeans ACC: 0.6423 | NMI: 0.7447 | Clusters: 30
#
# Epoch 6 | Train Loss: 0.0011
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 124 clusters
# Partition 2: 34 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6657 | NMI: 0.7911 | Clusters: 34
# KMeans ACC: 0.6917 | NMI: 0.7614 | Clusters: 30
#
# Epoch 7 | Train Loss: 0.0002
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 128 clusters
# Partition 2: 30 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.6940 | NMI: 0.7872 | Clusters: 30
# KMeans ACC: 0.6603 | NMI: 0.7411 | Clusters: 30
#
# Epoch 8 | Train Loss: 0.0002
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 131 clusters
# Partition 2: 33 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7133 | NMI: 0.7990 | Clusters: 33
# KMeans ACC: 0.6840 | NMI: 0.7491 | Clusters: 30
#
# Epoch 9 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 605 clusters
# Partition 1: 138 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6823 | NMI: 0.7814 | Clusters: 35
# KMeans ACC: 0.6743 | NMI: 0.7493 | Clusters: 30
#
# Epoch 10 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 135 clusters
# Partition 2: 36 clusters
# Partition 3: 7 clusters
# FINCH ACC: 0.6830 | NMI: 0.7952 | Clusters: 36
# KMeans ACC: 0.6770 | NMI: 0.7505 | Clusters: 30
#
# Epoch 11 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 609 clusters
# Partition 1: 137 clusters
# Partition 2: 36 clusters
# Partition 3: 6 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.7077 | NMI: 0.7907 | Clusters: 36
# KMeans ACC: 0.5953 | NMI: 0.7221 | Clusters: 30
#
# Epoch 12 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 606 clusters
# Partition 1: 135 clusters
# Partition 2: 33 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7253 | NMI: 0.8075 | Clusters: 33
# KMeans ACC: 0.6983 | NMI: 0.7493 | Clusters: 30
#
# Epoch 13 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 603 clusters
# Partition 1: 130 clusters
# Partition 2: 33 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6750 | NMI: 0.7812 | Clusters: 33
# KMeans ACC: 0.6817 | NMI: 0.7440 | Clusters: 30
#
# Epoch 14 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 613 clusters
# Partition 1: 133 clusters
# Partition 2: 36 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6983 | NMI: 0.7883 | Clusters: 36
# KMeans ACC: 0.6917 | NMI: 0.7558 | Clusters: 30
#
# Epoch 15 | Train Loss: 0.0001
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 131 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6950 | NMI: 0.7906 | Clusters: 35
# KMeans ACC: 0.6187 | NMI: 0.7311 | Clusters: 30
#
# Epoch 16 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 611 clusters
# Partition 1: 140 clusters
# Partition 2: 35 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6393 | NMI: 0.7741 | Clusters: 35
# KMeans ACC: 0.7343 | NMI: 0.7681 | Clusters: 30
#
# Epoch 17 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 137 clusters
# Partition 2: 37 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6400 | NMI: 0.7682 | Clusters: 37
# KMeans ACC: 0.6937 | NMI: 0.7566 | Clusters: 30
#
# Epoch 18 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 613 clusters
# Partition 1: 127 clusters
# Partition 2: 32 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6323 | NMI: 0.7731 | Clusters: 32
# KMeans ACC: 0.6710 | NMI: 0.7289 | Clusters: 30
#
# Epoch 19 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 606 clusters
# Partition 1: 132 clusters
# Partition 2: 38 clusters
# Partition 3: 12 clusters
# Partition 4: 4 clusters
# Partition 5: 2 clusters
# FINCH ACC: 0.6330 | NMI: 0.7897 | Clusters: 38
# KMeans ACC: 0.6657 | NMI: 0.7353 | Clusters: 30
#
# Epoch 20 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 611 clusters
# Partition 1: 135 clusters
# Partition 2: 38 clusters
# Partition 3: 9 clusters
# Partition 4: 4 clusters
# FINCH ACC: 0.6803 | NMI: 0.7851 | Clusters: 38
# KMeans ACC: 0.6680 | NMI: 0.7275 | Clusters: 30
#
# Epoch 21 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 616 clusters
# Partition 1: 141 clusters
# Partition 2: 37 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6950 | NMI: 0.7933 | Clusters: 37
# KMeans ACC: 0.6957 | NMI: 0.7466 | Clusters: 30
#
# Epoch 22 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 609 clusters
# Partition 1: 127 clusters
# Partition 2: 31 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6593 | NMI: 0.7731 | Clusters: 31
# KMeans ACC: 0.5903 | NMI: 0.7158 | Clusters: 30
#
# Epoch 23 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 133 clusters
# Partition 2: 36 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6750 | NMI: 0.7893 | Clusters: 36
# KMeans ACC: 0.6493 | NMI: 0.7436 | Clusters: 30
#
# Epoch 24 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 602 clusters
# Partition 1: 130 clusters
# Partition 2: 33 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6303 | NMI: 0.7773 | Clusters: 33
# KMeans ACC: 0.6483 | NMI: 0.7433 | Clusters: 30
#
# Epoch 25 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 604 clusters
# Partition 1: 134 clusters
# Partition 2: 36 clusters
# Partition 3: 11 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6637 | NMI: 0.7836 | Clusters: 36
# KMeans ACC: 0.6933 | NMI: 0.7534 | Clusters: 30
#
# Epoch 26 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 604 clusters
# Partition 1: 125 clusters
# Partition 2: 31 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.6337 | NMI: 0.7622 | Clusters: 31
# KMeans ACC: 0.6927 | NMI: 0.7528 | Clusters: 30
#
# Epoch 27 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 602 clusters
# Partition 1: 137 clusters
# Partition 2: 38 clusters
# Partition 3: 11 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6427 | NMI: 0.7704 | Clusters: 38
# KMeans ACC: 0.6980 | NMI: 0.7526 | Clusters: 30
#
# Epoch 28 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 129 clusters
# Partition 2: 38 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.7137 | NMI: 0.7934 | Clusters: 38
# KMeans ACC: 0.6887 | NMI: 0.7449 | Clusters: 30
#
# Epoch 29 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 606 clusters
# Partition 1: 138 clusters
# Partition 2: 39 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6520 | NMI: 0.7737 | Clusters: 39
# KMeans ACC: 0.6890 | NMI: 0.7444 | Clusters: 30
#
# Epoch 30 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 606 clusters
# Partition 1: 133 clusters
# Partition 2: 37 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6163 | NMI: 0.7612 | Clusters: 37
# KMeans ACC: 0.6563 | NMI: 0.7324 | Clusters: 30
#
# Epoch 31 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 609 clusters
# Partition 1: 128 clusters
# Partition 2: 40 clusters
# Partition 3: 11 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6593 | NMI: 0.7846 | Clusters: 40
# KMeans ACC: 0.6560 | NMI: 0.7310 | Clusters: 30
#
# Epoch 32 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 604 clusters
# Partition 1: 136 clusters
# Partition 2: 37 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6067 | NMI: 0.7660 | Clusters: 37
# KMeans ACC: 0.6783 | NMI: 0.7476 | Clusters: 30
#
# Epoch 33 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 610 clusters
# Partition 1: 136 clusters
# Partition 2: 37 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6973 | NMI: 0.7925 | Clusters: 37
# KMeans ACC: 0.6790 | NMI: 0.7478 | Clusters: 30
#
# Epoch 34 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 612 clusters
# Partition 1: 129 clusters
# Partition 2: 38 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6583 | NMI: 0.7803 | Clusters: 38
# KMeans ACC: 0.6647 | NMI: 0.7451 | Clusters: 30
#
# Epoch 35 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 613 clusters
# Partition 1: 134 clusters
# Partition 2: 31 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6537 | NMI: 0.7756 | Clusters: 31
# KMeans ACC: 0.6413 | NMI: 0.7395 | Clusters: 30
#
# Epoch 36 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 139 clusters
# Partition 2: 40 clusters
# Partition 3: 12 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6657 | NMI: 0.7828 | Clusters: 40
# KMeans ACC: 0.6447 | NMI: 0.7409 | Clusters: 30
#
# Epoch 37 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 607 clusters
# Partition 1: 136 clusters
# Partition 2: 36 clusters
# Partition 3: 8 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6933 | NMI: 0.7800 | Clusters: 36
# KMeans ACC: 0.6257 | NMI: 0.7327 | Clusters: 30
#
# Epoch 38 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 136 clusters
# Partition 2: 38 clusters
# Partition 3: 10 clusters
# Partition 4: 4 clusters
# FINCH ACC: 0.6780 | NMI: 0.7841 | Clusters: 38
# KMeans ACC: 0.6577 | NMI: 0.7366 | Clusters: 30
#
# Epoch 39 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 605 clusters
# Partition 1: 135 clusters
# Partition 2: 37 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6610 | NMI: 0.7763 | Clusters: 37
# KMeans ACC: 0.6907 | NMI: 0.7498 | Clusters: 30
#
# Epoch 40 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 137 clusters
# Partition 2: 35 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6217 | NMI: 0.7572 | Clusters: 35
# KMeans ACC: 0.6783 | NMI: 0.7505 | Clusters: 30
#
# Epoch 41 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 606 clusters
# Partition 1: 131 clusters
# Partition 2: 38 clusters
# Partition 3: 7 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6793 | NMI: 0.7830 | Clusters: 38
# KMeans ACC: 0.6010 | NMI: 0.7303 | Clusters: 30
#
# Epoch 42 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 136 clusters
# Partition 2: 39 clusters
# Partition 3: 11 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6497 | NMI: 0.7696 | Clusters: 39
# KMeans ACC: 0.6487 | NMI: 0.7389 | Clusters: 30
#
# Epoch 43 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 613 clusters
# Partition 1: 130 clusters
# Partition 2: 36 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6563 | NMI: 0.7793 | Clusters: 36
# KMeans ACC: 0.6547 | NMI: 0.7425 | Clusters: 30
#
# Epoch 44 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 135 clusters
# Partition 2: 34 clusters
# Partition 3: 6 clusters
# FINCH ACC: 0.6917 | NMI: 0.7873 | Clusters: 34
# KMeans ACC: 0.6480 | NMI: 0.7400 | Clusters: 30
#
# Epoch 45 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 614 clusters
# Partition 1: 132 clusters
# Partition 2: 38 clusters
# Partition 3: 11 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6407 | NMI: 0.7778 | Clusters: 38
# KMeans ACC: 0.6167 | NMI: 0.7245 | Clusters: 30
#
# Epoch 46 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 131 clusters
# Partition 2: 35 clusters
# Partition 3: 9 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6330 | NMI: 0.7743 | Clusters: 35
# KMeans ACC: 0.6907 | NMI: 0.7478 | Clusters: 30
#
# Epoch 47 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 608 clusters
# Partition 1: 133 clusters
# Partition 2: 35 clusters
# Partition 3: 8 clusters
# Partition 4: 2 clusters
# FINCH ACC: 0.6697 | NMI: 0.7782 | Clusters: 35
# KMeans ACC: 0.6970 | NMI: 0.7506 | Clusters: 30
#
# Epoch 48 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 619 clusters
# Partition 1: 135 clusters
# Partition 2: 38 clusters
# Partition 3: 9 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6860 | NMI: 0.7952 | Clusters: 38
# KMeans ACC: 0.6950 | NMI: 0.7518 | Clusters: 30
#
# Epoch 49 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 615 clusters
# Partition 1: 139 clusters
# Partition 2: 36 clusters
# Partition 3: 9 clusters
# FINCH ACC: 0.6913 | NMI: 0.7830 | Clusters: 36
# KMeans ACC: 0.6627 | NMI: 0.7462 | Clusters: 30
#
# Epoch 50 | Train Loss: 0.0000
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 615 clusters
# Partition 1: 127 clusters
# Partition 2: 36 clusters
# Partition 3: 10 clusters
# Partition 4: 3 clusters
# FINCH ACC: 0.6883 | NMI: 0.7850 | Clusters: 36
# KMeans ACC: 0.7187 | NMI: 0.7568 | Clusters: 30
#
# Using PyNNDescent to compute 1st-neighbours at this step ...
# Step PyNNDescent done ...
# Partition 0: 616 clusters
# Partition 1: 138 clusters
# Partition 2: 35 clusters
# Partition 3: 10 clusters
# Partition 4: 2 clusters
#
# FINCH Clustering Performance:
# Clustering Accuracy (ACC): 0.6277
# Normalized Mutual Information (NMI): 0.7668
# Number of clusters found: 35
#
# K-Means Clustering Performance: 30 Clusters
# Clustering Accuracy (ACC): 0.7187
# Normalized Mutual Information (NMI): 0.7568
# Number of clusters found: 30
#
# 📄 Hasil clustering disimpan di: clustering_metrics_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_4.csv
# 📄 Partisi FINCH disimpan di: finch_partitions_per_epoch_vit_b_16_finetuned_22labeled_30unlabeled_trial_4.csv
# Results saved to clustering_results_vit_b_16_finetuned_22labeled_30unlabeled_FINCH_KMEANS.csv
